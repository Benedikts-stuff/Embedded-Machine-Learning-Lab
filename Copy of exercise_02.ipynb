# %% [markdown]
# # Embedded ML Lab - Excercise 0 - Intro Training
#
# Now that we have covered Neural Network Inference, we come to the training of neural networks. We reuse the LeNet from the previous exercise.
#
# <span style="color:green">Your Task:</span>
# * <span style="color:green">Copy your implementation of the LeNet from the last excercise into Cell1</span>
#
# In Cell 2 the dataset is already prepared as a dataloader (using batch_size 32). Additionally, the images are already zero-centered and normalized. We have two separate data_loaders: `test_loader` for testing the accuracy of the model, and `train_data` for training the model. These two should not be mixed for their tasks. You can iterate over the batches of a dataloader by using `for idx, (input, targets) in enumerate(dataloader):`
#
# Before we start with training, we need to write two functions. The first is `correct_predictions(outputs, targets)`, where you can reuse code from exercise_00. This function takes the outputs and targets as input and returns an int with the number of correct predictions in the batch.
# The second function `test_net(net, device)`. This function iterates over the testloader, applies the network's forward pass, and returns the overall accuracy of the model (all correct predictions of the testset overall testset predictions)
#
# <span style="color:green">Your Tasks:</span>
# * <span style="color:green">Implement the `correct_predictions` function (Cell 3)</span>
# * <span style="color:green">Implement the `test_net` function (Cell 4)</span>
#     * <span style="color:green">First set the network in evaluation mode with `.eval()` </span>
#     * <span style="color:green">Iterate over the batches in the dataloader</span>
#     * <span style="color:green">For each batch calculate the correct detected images</span>
#     * NOTE: you can also only iterate over a fraction of batches to save some time
#     * <span style="color:green">Return the overall Accuracy</span>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#---to-be-done-by-student---
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()

        #---to-be-done-by-student---
        self.conv1 = nn.Conv2d(1, 6, 3, 1, 0)
        self.conv2 = nn.Conv2d(6, 16, 3, 1, 0)
        self.fc1 = nn.Linear(400, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        #---end---------------------
        return

    def forward(self,x):
        #---to-be-done-by-student---
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = x.flatten(1)

        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        #---end---------------------
        return x
#---end---------------------
net = LeNet()

# %%
import torchvision
import time

test_loader = torch.utils.data.DataLoader(torchvision.datasets.MNIST('.', train=False, download=True, transform=torchvision.transforms.Compose([
                                                torchvision.transforms.ToTensor(), torchvision.transforms.Normalize(
                                                (0.1307, ), (0.3081)) ])), batch_size=64, shuffle=False, drop_last=True)

train_loader = torch.utils.data.DataLoader(torchvision.datasets.MNIST('.', train=True, download=True, transform=torchvision.transforms.Compose([
                                                torchvision.transforms.ToTensor(), torchvision.transforms.Normalize(
                                                (0.1307, ), (0.3081)) ])), batch_size=64, shuffle=False, drop_last=True)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
def correct_predictions(outputs, targets):
    correct_predictions = 0
    for i in range(len(targets)):
        correct_predictions += int(torch.argmax(outputs[i]) == targets[i])

    #---end---------------------
    return correct_predictions

# %%
def test_net(net, device):
    #---to-be-done-by-student---
    net.eval()
    overall = test_loader.batch_size
    for batch_idx, (inputs, targets) in enumerate(test_loader):
        outputs = net(inputs)
        correct_detected = correct_predictions(outputs, targets)

    #---end---------------------
    return float(correct_detected/overall)

# %% [markdown]
# Now that we have these two helper functions we come to training the network. Some parts are already given. You can do the training either on the cpu or on the gpu (gpu should be faster).
#
# First we define an optimizer `optimizer = torch.optim.SGD(net.parameters(), lr=0.01)` and hand in the model's parameters (e.g., weights and biases of the conv and linear layers). Besides the model's parameters, we set the learning rate to 0.01. The learning defines the step size for updating the parameters based on their gradients.
#
# Also, we require a loss function `loss_function = nn.CrossEntropyLoss()`, which defines the error (loss) between the output of the network and the desired output target.
# To train the network we iterate over the dataset several times (for 5 epochs).
#
# We can split the training into five parts (for each training batch):
# <span style="color:green">Your Tasks:</span>
# * <span style="color:green">**Clean old gradients**: Remove the previous gradients of the parameters by calling `optimizer.zero_grad()`.</span>
# * <span style="color:green">**Forward Pass**: Similar to the previous inference experiments,
#     calculate the network's output.</span>
# * <span style="color:green">**Loss**: Calculate the loss by using `loss_function(outputs, targets)`.</span>
# * <span style="color:green">**Backpropagation of the error**: Call `.backward()` on the loss tensor and Pytorch will automatically calculate the respective gradients of the modules with respect to the input and parameters.</span>
# * <span style="color:green">**Step**: As the last step, modify the parameters based on their gradients by calling `optimizer.step()`.</span>
#
# Plotting the accuracy and loss of the model:
#
# <span style="color:green">Your Tasks:</span>
# * <span style="color:green">Collect the network's loss for each batch.
# * <span style="color:green">After every 100 batches calculate the networks average_loss (of last 100 batches).</span>
# * <span style="color:green">Similar, calculate the models accuracy using using your defined `test_net` function.</span>
# * <span style="color:green">Append the average loss and the accuracy to `loss_list` and `acc_list`, respectively.</span>

# %%
n_epochs = 5
loss_list = []
acc_list = []
torch.backends.mkldnn.enabled = False

device = torch.device('mps')
net.to(device).float()

optimizer = torch.optim.SGD(net.parameters(), lr=0.01)
#optimizer = torch.optim.Adam(net.parameters(), lr=0.1)
loss_function = nn.CrossEntropyLoss()

#---to-be-done-by-student---
loss = 0
loss_avg = []
accuracy = []
#---end---------------------
for epoch_n in range(n_epochs):
    net.train()
    running_loss = 0.0
    running_count = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs  = inputs.to(device, dtype=torch.float32).contiguous()  # NCHW + contiguous
        targets = targets.to(device, dtype=torch.long)
        acc_window = []
        print(f"Batch {batch_idx} of {len(train_loader)} epoch {epoch_n}")

        #---to-be-done-by-student---
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = loss_function(outputs, targets)
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            preds = outputs.argmax(dim=1)
            acc_batch = (preds == targets).float().mean().item()
        acc_window.append(acc_batch)
        
        running_loss += loss.item()
        running_count += 1
        #---end---------------------
        if batch_idx % 100 == 0:
            loss_window_avg = running_loss / running_count
            acc_window_avg  = sum(acc_window) / len(acc_window)

            loss_list.append(loss_window_avg)
            acc_list.append(acc_window_avg)

            running_loss = 0.0
            running_count = 0
            acc_window.clear()

            #---to-be-done-by-student---

            #---end---------------------
# Out:
# Batch 0 of 937 epoch 0
# Batch 1 of 937 epoch 0
# Batch 2 of 937 epoch 0
# Batch 3 of 937 epoch 0
# Batch 4 of 937 epoch 0
# Batch 5 of 937 epoch 0
# Batch 6 of 937 epoch 0
# Batch 7 of 937 epoch 0
# Batch 8 of 937 epoch 0
# Batch 9 of 937 epoch 0
# Batch 10 of 937 epoch 0
# Batch 11 of 937 epoch 0
# Batch 12 of 937 epoch 0
# Batch 13 of 937 epoch 0
# Batch 14 of 937 epoch 0
# Batch 15 of 937 epoch 0
# Batch 16 of 937 epoch 0
# Batch 17 of 937 epoch 0
# Batch 18 of 937 epoch 0
# Batch 19 of 937 epoch 0
# Batch 20 of 937 epoch 0
# Batch 21 of 937 epoch 0
# Batch 22 of 937 epoch 0
# Batch 23 of 937 epoch 0
# Batch 24 of 937 epoch 0
# Batch 25 of 937 epoch 0
# Batch 26 of 937 epoch 0
# Batch 27 of 937 epoch 0
# Batch 28 of 937 epoch 0
# Batch 29 of 937 epoch 0
# Batch 30 of 937 epoch 0
# Batch 31 of 937 epoch 0
# Batch 32 of 937 epoch 0
# Batch 33 of 937 epoch 0
# Batch 34 of 937 epoch 0
# Batch 35 of 937 epoch 0
# Batch 36 of 937 epoch 0
# Batch 37 of 937 epoch 0
# Batch 38 of 937 epoch 0
# Batch 39 of 937 epoch 0
# Batch 40 of 937 epoch 0
# Batch 41 of 937 epoch 0
# Batch 42 of 937 epoch 0
# Batch 43 of 937 epoch 0
# Batch 44 of 937 epoch 0
# Batch 45 of 937 epoch 0
# Batch 46 of 937 epoch 0
# Batch 47 of 937 epoch 0
# Batch 48 of 937 epoch 0
# Batch 49 of 937 epoch 0
# Batch 50 of 937 epoch 0
# Batch 51 of 937 epoch 0
# Batch 52 of 937 epoch 0
# Batch 53 of 937 epoch 0
# Batch 54 of 937 epoch 0
# Batch 55 of 937 epoch 0
# Batch 56 of 937 epoch 0
# Batch 57 of 937 epoch 0
# Batch 58 of 937 epoch 0
# Batch 59 of 937 epoch 0
# Batch 60 of 937 epoch 0
# Batch 61 of 937 epoch 0
# Batch 62 of 937 epoch 0
# Batch 63 of 937 epoch 0
# Batch 64 of 937 epoch 0
# Batch 65 of 937 epoch 0
# Batch 66 of 937 epoch 0
# Batch 67 of 937 epoch 0
# Batch 68 of 937 epoch 0
# Batch 69 of 937 epoch 0
# Batch 70 of 937 epoch 0
# Batch 71 of 937 epoch 0
# Batch 72 of 937 epoch 0
# Batch 73 of 937 epoch 0
# Batch 74 of 937 epoch 0
# Batch 75 of 937 epoch 0
# Batch 76 of 937 epoch 0
# Batch 77 of 937 epoch 0
# Batch 78 of 937 epoch 0
# Batch 79 of 937 epoch 0
# Batch 80 of 937 epoch 0
# Batch 81 of 937 epoch 0
# Batch 82 of 937 epoch 0
# Batch 83 of 937 epoch 0
# Batch 84 of 937 epoch 0
# Batch 85 of 937 epoch 0
# Batch 86 of 937 epoch 0
# Batch 87 of 937 epoch 0
# Batch 88 of 937 epoch 0
# Batch 89 of 937 epoch 0
# Batch 90 of 937 epoch 0
# Batch 91 of 937 epoch 0
# Batch 92 of 937 epoch 0
# Batch 93 of 937 epoch 0
# Batch 94 of 937 epoch 0
# Batch 95 of 937 epoch 0
# Batch 96 of 937 epoch 0
# Batch 97 of 937 epoch 0
# Batch 98 of 937 epoch 0
# Batch 99 of 937 epoch 0
# Batch 100 of 937 epoch 0
# Batch 101 of 937 epoch 0
# Batch 102 of 937 epoch 0
# Batch 103 of 937 epoch 0
# Batch 104 of 937 epoch 0
# Batch 105 of 937 epoch 0
# Batch 106 of 937 epoch 0
# Batch 107 of 937 epoch 0
# Batch 108 of 937 epoch 0
# Batch 109 of 937 epoch 0
# Batch 110 of 937 epoch 0
# Batch 111 of 937 epoch 0
# Batch 112 of 937 epoch 0
# Batch 113 of 937 epoch 0
# Batch 114 of 937 epoch 0
# Batch 115 of 937 epoch 0
# Batch 116 of 937 epoch 0
# Batch 117 of 937 epoch 0
# Batch 118 of 937 epoch 0
# Batch 119 of 937 epoch 0
# Batch 120 of 937 epoch 0
# Batch 121 of 937 epoch 0
# Batch 122 of 937 epoch 0
# Batch 123 of 937 epoch 0
# Batch 124 of 937 epoch 0
# Batch 125 of 937 epoch 0
# Batch 126 of 937 epoch 0
# Batch 127 of 937 epoch 0
# Batch 128 of 937 epoch 0
# Batch 129 of 937 epoch 0
# Batch 130 of 937 epoch 0
# Batch 131 of 937 epoch 0
# Batch 132 of 937 epoch 0
# Batch 133 of 937 epoch 0
# Batch 134 of 937 epoch 0
# Batch 135 of 937 epoch 0
# Batch 136 of 937 epoch 0
# Batch 137 of 937 epoch 0
# Batch 138 of 937 epoch 0
# Batch 139 of 937 epoch 0
# Batch 140 of 937 epoch 0
# Batch 141 of 937 epoch 0
# Batch 142 of 937 epoch 0
# Batch 143 of 937 epoch 0
# Batch 144 of 937 epoch 0
# Batch 145 of 937 epoch 0
# Batch 146 of 937 epoch 0
# Batch 147 of 937 epoch 0
# Batch 148 of 937 epoch 0
# Batch 149 of 937 epoch 0
# Batch 150 of 937 epoch 0
# Batch 151 of 937 epoch 0
# Batch 152 of 937 epoch 0
# Batch 153 of 937 epoch 0
# Batch 154 of 937 epoch 0
# Batch 155 of 937 epoch 0
# Batch 156 of 937 epoch 0
# Batch 157 of 937 epoch 0
# Batch 158 of 937 epoch 0
# Batch 159 of 937 epoch 0
# Batch 160 of 937 epoch 0
# Batch 161 of 937 epoch 0
# Batch 162 of 937 epoch 0
# Batch 163 of 937 epoch 0
# Batch 164 of 937 epoch 0
# Batch 165 of 937 epoch 0
# Batch 166 of 937 epoch 0
# Batch 167 of 937 epoch 0
# Batch 168 of 937 epoch 0
# Batch 169 of 937 epoch 0
# Batch 170 of 937 epoch 0
# Batch 171 of 937 epoch 0
# Batch 172 of 937 epoch 0
# Batch 173 of 937 epoch 0
# Batch 174 of 937 epoch 0
# Batch 175 of 937 epoch 0
# Batch 176 of 937 epoch 0
# Batch 177 of 937 epoch 0
# Batch 178 of 937 epoch 0
# Batch 179 of 937 epoch 0
# Batch 180 of 937 epoch 0
# Batch 181 of 937 epoch 0
# Batch 182 of 937 epoch 0
# Batch 183 of 937 epoch 0
# Batch 184 of 937 epoch 0
# Batch 185 of 937 epoch 0
# Batch 186 of 937 epoch 0
# Batch 187 of 937 epoch 0
# Batch 188 of 937 epoch 0
# Batch 189 of 937 epoch 0
# Batch 190 of 937 epoch 0
# Batch 191 of 937 epoch 0
# Batch 192 of 937 epoch 0
# Batch 193 of 937 epoch 0
# Batch 194 of 937 epoch 0
# Batch 195 of 937 epoch 0
# Batch 196 of 937 epoch 0
# Batch 197 of 937 epoch 0
# Batch 198 of 937 epoch 0
# Batch 199 of 937 epoch 0
# Batch 200 of 937 epoch 0
# Batch 201 of 937 epoch 0
# Batch 202 of 937 epoch 0
# Batch 203 of 937 epoch 0
# Batch 204 of 937 epoch 0
# Batch 205 of 937 epoch 0
# Batch 206 of 937 epoch 0
# Batch 207 of 937 epoch 0
# Batch 208 of 937 epoch 0
# Batch 209 of 937 epoch 0
# Batch 210 of 937 epoch 0
# Batch 211 of 937 epoch 0
# Batch 212 of 937 epoch 0
# Batch 213 of 937 epoch 0
# Batch 214 of 937 epoch 0
# Batch 215 of 937 epoch 0
# Batch 216 of 937 epoch 0
# Batch 217 of 937 epoch 0
# Batch 218 of 937 epoch 0
# Batch 219 of 937 epoch 0
# Batch 220 of 937 epoch 0
# Batch 221 of 937 epoch 0
# Batch 222 of 937 epoch 0
# Batch 223 of 937 epoch 0
# Batch 224 of 937 epoch 0
# Batch 225 of 937 epoch 0
# Batch 226 of 937 epoch 0
# Batch 227 of 937 epoch 0
# Batch 228 of 937 epoch 0
# Batch 229 of 937 epoch 0
# Batch 230 of 937 epoch 0
# Batch 231 of 937 epoch 0
# Batch 232 of 937 epoch 0
# Batch 233 of 937 epoch 0
# Batch 234 of 937 epoch 0
# Batch 235 of 937 epoch 0
# Batch 236 of 937 epoch 0
# Batch 237 of 937 epoch 0
# Batch 238 of 937 epoch 0
# Batch 239 of 937 epoch 0
# Batch 240 of 937 epoch 0
# Batch 241 of 937 epoch 0
# Batch 242 of 937 epoch 0
# Batch 243 of 937 epoch 0
# Batch 244 of 937 epoch 0
# Batch 245 of 937 epoch 0
# Batch 246 of 937 epoch 0
# Batch 247 of 937 epoch 0
# Batch 248 of 937 epoch 0
# Batch 249 of 937 epoch 0
# Batch 250 of 937 epoch 0
# Batch 251 of 937 epoch 0
# Batch 252 of 937 epoch 0
# Batch 253 of 937 epoch 0
# Batch 254 of 937 epoch 0
# Batch 255 of 937 epoch 0
# Batch 256 of 937 epoch 0
# Batch 257 of 937 epoch 0
# Batch 258 of 937 epoch 0
# Batch 259 of 937 epoch 0
# Batch 260 of 937 epoch 0
# Batch 261 of 937 epoch 0
# Batch 262 of 937 epoch 0
# Batch 263 of 937 epoch 0
# Batch 264 of 937 epoch 0
# Batch 265 of 937 epoch 0
# Batch 266 of 937 epoch 0
# Batch 267 of 937 epoch 0
# Batch 268 of 937 epoch 0
# Batch 269 of 937 epoch 0
# Batch 270 of 937 epoch 0
# Batch 271 of 937 epoch 0
# Batch 272 of 937 epoch 0
# Batch 273 of 937 epoch 0
# Batch 274 of 937 epoch 0
# Batch 275 of 937 epoch 0
# Batch 276 of 937 epoch 0
# Batch 277 of 937 epoch 0
# Batch 278 of 937 epoch 0
# Batch 279 of 937 epoch 0
# Batch 280 of 937 epoch 0
# Batch 281 of 937 epoch 0
# Batch 282 of 937 epoch 0
# Batch 283 of 937 epoch 0
# Batch 284 of 937 epoch 0
# Batch 285 of 937 epoch 0
# Batch 286 of 937 epoch 0
# Batch 287 of 937 epoch 0
# Batch 288 of 937 epoch 0
# Batch 289 of 937 epoch 0
# Batch 290 of 937 epoch 0
# Batch 291 of 937 epoch 0
# Batch 292 of 937 epoch 0
# Batch 293 of 937 epoch 0
# Batch 294 of 937 epoch 0
# Batch 295 of 937 epoch 0
# Batch 296 of 937 epoch 0
# Batch 297 of 937 epoch 0
# Batch 298 of 937 epoch 0
# Batch 299 of 937 epoch 0
# Batch 300 of 937 epoch 0
# Batch 301 of 937 epoch 0
# Batch 302 of 937 epoch 0
# Batch 303 of 937 epoch 0
# Batch 304 of 937 epoch 0
# Batch 305 of 937 epoch 0
# Batch 306 of 937 epoch 0
# Batch 307 of 937 epoch 0
# Batch 308 of 937 epoch 0
# Batch 309 of 937 epoch 0
# Batch 310 of 937 epoch 0
# Batch 311 of 937 epoch 0
# Batch 312 of 937 epoch 0
# Batch 313 of 937 epoch 0
# Batch 314 of 937 epoch 0
# Batch 315 of 937 epoch 0
# Batch 316 of 937 epoch 0
# Batch 317 of 937 epoch 0
# Batch 318 of 937 epoch 0
# Batch 319 of 937 epoch 0
# Batch 320 of 937 epoch 0
# Batch 321 of 937 epoch 0
# Batch 322 of 937 epoch 0
# Batch 323 of 937 epoch 0
# Batch 324 of 937 epoch 0
# Batch 325 of 937 epoch 0
# Batch 326 of 937 epoch 0
# Batch 327 of 937 epoch 0
# Batch 328 of 937 epoch 0
# Batch 329 of 937 epoch 0
# Batch 330 of 937 epoch 0
# Batch 331 of 937 epoch 0
# Batch 332 of 937 epoch 0
# Batch 333 of 937 epoch 0
# Batch 334 of 937 epoch 0
# Batch 335 of 937 epoch 0
# Batch 336 of 937 epoch 0
# Batch 337 of 937 epoch 0
# Batch 338 of 937 epoch 0
# Batch 339 of 937 epoch 0
# Batch 340 of 937 epoch 0
# Batch 341 of 937 epoch 0
# Batch 342 of 937 epoch 0
# Batch 343 of 937 epoch 0
# Batch 344 of 937 epoch 0
# Batch 345 of 937 epoch 0
# Batch 346 of 937 epoch 0
# Batch 347 of 937 epoch 0
# Batch 348 of 937 epoch 0
# Batch 349 of 937 epoch 0
# Batch 350 of 937 epoch 0
# Batch 351 of 937 epoch 0
# Batch 352 of 937 epoch 0
# Batch 353 of 937 epoch 0
# Batch 354 of 937 epoch 0
# Batch 355 of 937 epoch 0
# Batch 356 of 937 epoch 0
# Batch 357 of 937 epoch 0
# Batch 358 of 937 epoch 0
# Batch 359 of 937 epoch 0
# Batch 360 of 937 epoch 0
# Batch 361 of 937 epoch 0
# Batch 362 of 937 epoch 0
# Batch 363 of 937 epoch 0
# Batch 364 of 937 epoch 0
# Batch 365 of 937 epoch 0
# Batch 366 of 937 epoch 0
# Batch 367 of 937 epoch 0
# Batch 368 of 937 epoch 0
# Batch 369 of 937 epoch 0
# Batch 370 of 937 epoch 0
# Batch 371 of 937 epoch 0
# Batch 372 of 937 epoch 0
# Batch 373 of 937 epoch 0
# Batch 374 of 937 epoch 0
# Batch 375 of 937 epoch 0
# Batch 376 of 937 epoch 0
# Batch 377 of 937 epoch 0
# Batch 378 of 937 epoch 0
# Batch 379 of 937 epoch 0
# Batch 380 of 937 epoch 0
# Batch 381 of 937 epoch 0
# Batch 382 of 937 epoch 0
# Batch 383 of 937 epoch 0
# Batch 384 of 937 epoch 0
# Batch 385 of 937 epoch 0
# Batch 386 of 937 epoch 0
# Batch 387 of 937 epoch 0
# Batch 388 of 937 epoch 0
# Batch 389 of 937 epoch 0
# Batch 390 of 937 epoch 0
# Batch 391 of 937 epoch 0
# Batch 392 of 937 epoch 0
# Batch 393 of 937 epoch 0
# Batch 394 of 937 epoch 0
# Batch 395 of 937 epoch 0
# Batch 396 of 937 epoch 0
# Batch 397 of 937 epoch 0
# Batch 398 of 937 epoch 0
# Batch 399 of 937 epoch 0
# Batch 400 of 937 epoch 0
# Batch 401 of 937 epoch 0
# Batch 402 of 937 epoch 0
# Batch 403 of 937 epoch 0
# Batch 404 of 937 epoch 0
# Batch 405 of 937 epoch 0
# Batch 406 of 937 epoch 0
# Batch 407 of 937 epoch 0
# Batch 408 of 937 epoch 0
# Batch 409 of 937 epoch 0
# Batch 410 of 937 epoch 0
# Batch 411 of 937 epoch 0
# Batch 412 of 937 epoch 0
# Batch 413 of 937 epoch 0
# Batch 414 of 937 epoch 0
# Batch 415 of 937 epoch 0
# Batch 416 of 937 epoch 0
# Batch 417 of 937 epoch 0
# Batch 418 of 937 epoch 0
# Batch 419 of 937 epoch 0
# Batch 420 of 937 epoch 0
# Batch 421 of 937 epoch 0
# Batch 422 of 937 epoch 0
# Batch 423 of 937 epoch 0
# Batch 424 of 937 epoch 0
# Batch 425 of 937 epoch 0
# Batch 426 of 937 epoch 0
# Batch 427 of 937 epoch 0
# Batch 428 of 937 epoch 0
# Batch 429 of 937 epoch 0
# Batch 430 of 937 epoch 0
# Batch 431 of 937 epoch 0
# Batch 432 of 937 epoch 0
# Batch 433 of 937 epoch 0
# Batch 434 of 937 epoch 0
# Batch 435 of 937 epoch 0
# Batch 436 of 937 epoch 0
# Batch 437 of 937 epoch 0
# Batch 438 of 937 epoch 0
# Batch 439 of 937 epoch 0
# Batch 440 of 937 epoch 0
# Batch 441 of 937 epoch 0
# Batch 442 of 937 epoch 0
# Batch 443 of 937 epoch 0
# Batch 444 of 937 epoch 0
# Batch 445 of 937 epoch 0
# Batch 446 of 937 epoch 0
# Batch 447 of 937 epoch 0
# Batch 448 of 937 epoch 0
# Batch 449 of 937 epoch 0
# Batch 450 of 937 epoch 0
# Batch 451 of 937 epoch 0
# Batch 452 of 937 epoch 0
# Batch 453 of 937 epoch 0
# Batch 454 of 937 epoch 0
# Batch 455 of 937 epoch 0
# Batch 456 of 937 epoch 0
# Batch 457 of 937 epoch 0
# Batch 458 of 937 epoch 0
# Batch 459 of 937 epoch 0
# Batch 460 of 937 epoch 0
# Batch 461 of 937 epoch 0
# Batch 462 of 937 epoch 0
# Batch 463 of 937 epoch 0
# Batch 464 of 937 epoch 0
# Batch 465 of 937 epoch 0
# Batch 466 of 937 epoch 0
# Batch 467 of 937 epoch 0
# Batch 468 of 937 epoch 0
# Batch 469 of 937 epoch 0
# Batch 470 of 937 epoch 0
# Batch 471 of 937 epoch 0
# Batch 472 of 937 epoch 0
# Batch 473 of 937 epoch 0
# Batch 474 of 937 epoch 0
# Batch 475 of 937 epoch 0
# Batch 476 of 937 epoch 0
# Batch 477 of 937 epoch 0
# Batch 478 of 937 epoch 0
# Batch 479 of 937 epoch 0
# Batch 480 of 937 epoch 0
# Batch 481 of 937 epoch 0
# Batch 482 of 937 epoch 0
# Batch 483 of 937 epoch 0
# Batch 484 of 937 epoch 0
# Batch 485 of 937 epoch 0
# Batch 486 of 937 epoch 0
# Batch 487 of 937 epoch 0
# Batch 488 of 937 epoch 0
# Batch 489 of 937 epoch 0
# Batch 490 of 937 epoch 0
# Batch 491 of 937 epoch 0
# Batch 492 of 937 epoch 0
# Batch 493 of 937 epoch 0
# Batch 494 of 937 epoch 0
# Batch 495 of 937 epoch 0
# Batch 496 of 937 epoch 0
# Batch 497 of 937 epoch 0
# Batch 498 of 937 epoch 0
# Batch 499 of 937 epoch 0
# Batch 500 of 937 epoch 0
# Batch 501 of 937 epoch 0
# Batch 502 of 937 epoch 0
# Batch 503 of 937 epoch 0
# Batch 504 of 937 epoch 0
# Batch 505 of 937 epoch 0
# Batch 506 of 937 epoch 0
# Batch 507 of 937 epoch 0
# Batch 508 of 937 epoch 0
# Batch 509 of 937 epoch 0
# Batch 510 of 937 epoch 0
# Batch 511 of 937 epoch 0
# Batch 512 of 937 epoch 0
# Batch 513 of 937 epoch 0
# Batch 514 of 937 epoch 0
# Batch 515 of 937 epoch 0
# Batch 516 of 937 epoch 0
# Batch 517 of 937 epoch 0
# Batch 518 of 937 epoch 0
# Batch 519 of 937 epoch 0
# Batch 520 of 937 epoch 0
# Batch 521 of 937 epoch 0
# Batch 522 of 937 epoch 0
# Batch 523 of 937 epoch 0
# Batch 524 of 937 epoch 0
# Batch 525 of 937 epoch 0
# Batch 526 of 937 epoch 0
# Batch 527 of 937 epoch 0
# Batch 528 of 937 epoch 0
# Batch 529 of 937 epoch 0
# Batch 530 of 937 epoch 0
# Batch 531 of 937 epoch 0
# Batch 532 of 937 epoch 0
# Batch 533 of 937 epoch 0
# Batch 534 of 937 epoch 0
# Batch 535 of 937 epoch 0
# Batch 536 of 937 epoch 0
# Batch 537 of 937 epoch 0
# Batch 538 of 937 epoch 0
# Batch 539 of 937 epoch 0
# Batch 540 of 937 epoch 0
# Batch 541 of 937 epoch 0
# Batch 542 of 937 epoch 0
# Batch 543 of 937 epoch 0
# Batch 544 of 937 epoch 0
# Batch 545 of 937 epoch 0
# Batch 546 of 937 epoch 0
# Batch 547 of 937 epoch 0
# Batch 548 of 937 epoch 0
# Batch 549 of 937 epoch 0
# Batch 550 of 937 epoch 0
# Batch 551 of 937 epoch 0
# Batch 552 of 937 epoch 0
# Batch 553 of 937 epoch 0
# Batch 554 of 937 epoch 0
# Batch 555 of 937 epoch 0
# Batch 556 of 937 epoch 0
# Batch 557 of 937 epoch 0
# Batch 558 of 937 epoch 0
# Batch 559 of 937 epoch 0
# Batch 560 of 937 epoch 0
# Batch 561 of 937 epoch 0
# Batch 562 of 937 epoch 0
# Batch 563 of 937 epoch 0
# Batch 564 of 937 epoch 0
# Batch 565 of 937 epoch 0
# Batch 566 of 937 epoch 0
# Batch 567 of 937 epoch 0
# Batch 568 of 937 epoch 0
# Batch 569 of 937 epoch 0
# Batch 570 of 937 epoch 0
# Batch 571 of 937 epoch 0
# Batch 572 of 937 epoch 0
# Batch 573 of 937 epoch 0
# Batch 574 of 937 epoch 0
# Batch 575 of 937 epoch 0
# Batch 576 of 937 epoch 0
# Batch 577 of 937 epoch 0
# Batch 578 of 937 epoch 0
# Batch 579 of 937 epoch 0
# Batch 580 of 937 epoch 0
# Batch 581 of 937 epoch 0
# Batch 582 of 937 epoch 0
# Batch 583 of 937 epoch 0
# Batch 584 of 937 epoch 0
# Batch 585 of 937 epoch 0
# Batch 586 of 937 epoch 0
# Batch 587 of 937 epoch 0
# Batch 588 of 937 epoch 0
# Batch 589 of 937 epoch 0
# Batch 590 of 937 epoch 0
# Batch 591 of 937 epoch 0
# Batch 592 of 937 epoch 0
# Batch 593 of 937 epoch 0
# Batch 594 of 937 epoch 0
# Batch 595 of 937 epoch 0
# Batch 596 of 937 epoch 0
# Batch 597 of 937 epoch 0
# Batch 598 of 937 epoch 0
# Batch 599 of 937 epoch 0
# Batch 600 of 937 epoch 0
# Batch 601 of 937 epoch 0
# Batch 602 of 937 epoch 0
# Batch 603 of 937 epoch 0
# Batch 604 of 937 epoch 0
# Batch 605 of 937 epoch 0
# Batch 606 of 937 epoch 0
# Batch 607 of 937 epoch 0
# Batch 608 of 937 epoch 0
# Batch 609 of 937 epoch 0
# Batch 610 of 937 epoch 0
# Batch 611 of 937 epoch 0
# Batch 612 of 937 epoch 0
# Batch 613 of 937 epoch 0
# Batch 614 of 937 epoch 0
# Batch 615 of 937 epoch 0
# Batch 616 of 937 epoch 0
# Batch 617 of 937 epoch 0
# Batch 618 of 937 epoch 0
# Batch 619 of 937 epoch 0
# Batch 620 of 937 epoch 0
# Batch 621 of 937 epoch 0
# Batch 622 of 937 epoch 0
# Batch 623 of 937 epoch 0
# Batch 624 of 937 epoch 0
# Batch 625 of 937 epoch 0
# Batch 626 of 937 epoch 0
# Batch 627 of 937 epoch 0
# Batch 628 of 937 epoch 0
# Batch 629 of 937 epoch 0
# Batch 630 of 937 epoch 0
# Batch 631 of 937 epoch 0
# Batch 632 of 937 epoch 0
# Batch 633 of 937 epoch 0
# Batch 634 of 937 epoch 0
# Batch 635 of 937 epoch 0
# Batch 636 of 937 epoch 0
# Batch 637 of 937 epoch 0
# Batch 638 of 937 epoch 0
# Batch 639 of 937 epoch 0
# Batch 640 of 937 epoch 0
# Batch 641 of 937 epoch 0
# Batch 642 of 937 epoch 0
# Batch 643 of 937 epoch 0
# Batch 644 of 937 epoch 0
# Batch 645 of 937 epoch 0
# Batch 646 of 937 epoch 0
# Batch 647 of 937 epoch 0
# Batch 648 of 937 epoch 0
# Batch 649 of 937 epoch 0
# Batch 650 of 937 epoch 0
# Batch 651 of 937 epoch 0
# Batch 652 of 937 epoch 0
# Batch 653 of 937 epoch 0
# Batch 654 of 937 epoch 0
# Batch 655 of 937 epoch 0
# Batch 656 of 937 epoch 0
# Batch 657 of 937 epoch 0
# Batch 658 of 937 epoch 0
# Batch 659 of 937 epoch 0
# Batch 660 of 937 epoch 0
# Batch 661 of 937 epoch 0
# Batch 662 of 937 epoch 0
# Batch 663 of 937 epoch 0
# Batch 664 of 937 epoch 0
# Batch 665 of 937 epoch 0
# Batch 666 of 937 epoch 0
# Batch 667 of 937 epoch 0
# Batch 668 of 937 epoch 0
# Batch 669 of 937 epoch 0
# Batch 670 of 937 epoch 0
# Batch 671 of 937 epoch 0
# Batch 672 of 937 epoch 0
# Batch 673 of 937 epoch 0
# Batch 674 of 937 epoch 0
# Batch 675 of 937 epoch 0
# Batch 676 of 937 epoch 0
# Batch 677 of 937 epoch 0
# Batch 678 of 937 epoch 0
# Batch 679 of 937 epoch 0
# Batch 680 of 937 epoch 0
# Batch 681 of 937 epoch 0
# Batch 682 of 937 epoch 0
# Batch 683 of 937 epoch 0
# Batch 684 of 937 epoch 0
# Batch 685 of 937 epoch 0
# Batch 686 of 937 epoch 0
# Batch 687 of 937 epoch 0
# Batch 688 of 937 epoch 0
# Batch 689 of 937 epoch 0
# Batch 690 of 937 epoch 0
# Batch 691 of 937 epoch 0
# Batch 692 of 937 epoch 0
# Batch 693 of 937 epoch 0
# Batch 694 of 937 epoch 0
# Batch 695 of 937 epoch 0
# Batch 696 of 937 epoch 0
# Batch 697 of 937 epoch 0
# Batch 698 of 937 epoch 0
# Batch 699 of 937 epoch 0
# Batch 700 of 937 epoch 0
# Batch 701 of 937 epoch 0
# Batch 702 of 937 epoch 0
# Batch 703 of 937 epoch 0
# Batch 704 of 937 epoch 0
# Batch 705 of 937 epoch 0
# Batch 706 of 937 epoch 0
# Batch 707 of 937 epoch 0
# Batch 708 of 937 epoch 0
# Batch 709 of 937 epoch 0
# Batch 710 of 937 epoch 0
# Batch 711 of 937 epoch 0
# Batch 712 of 937 epoch 0
# Batch 713 of 937 epoch 0
# Batch 714 of 937 epoch 0
# Batch 715 of 937 epoch 0
# Batch 716 of 937 epoch 0
# Batch 717 of 937 epoch 0
# Batch 718 of 937 epoch 0
# Batch 719 of 937 epoch 0
# Batch 720 of 937 epoch 0
# Batch 721 of 937 epoch 0
# Batch 722 of 937 epoch 0
# Batch 723 of 937 epoch 0
# Batch 724 of 937 epoch 0
# Batch 725 of 937 epoch 0
# Batch 726 of 937 epoch 0
# Batch 727 of 937 epoch 0
# Batch 728 of 937 epoch 0
# Batch 729 of 937 epoch 0
# Batch 730 of 937 epoch 0
# Batch 731 of 937 epoch 0
# Batch 732 of 937 epoch 0
# Batch 733 of 937 epoch 0
# Batch 734 of 937 epoch 0
# Batch 735 of 937 epoch 0
# Batch 736 of 937 epoch 0
# Batch 737 of 937 epoch 0
# Batch 738 of 937 epoch 0
# Batch 739 of 937 epoch 0
# Batch 740 of 937 epoch 0
# Batch 741 of 937 epoch 0
# Batch 742 of 937 epoch 0
# Batch 743 of 937 epoch 0
# Batch 744 of 937 epoch 0
# Batch 745 of 937 epoch 0
# Batch 746 of 937 epoch 0
# Batch 747 of 937 epoch 0
# Batch 748 of 937 epoch 0
# Batch 749 of 937 epoch 0
# Batch 750 of 937 epoch 0
# Batch 751 of 937 epoch 0
# Batch 752 of 937 epoch 0
# Batch 753 of 937 epoch 0
# Batch 754 of 937 epoch 0
# Batch 755 of 937 epoch 0
# Batch 756 of 937 epoch 0
# Batch 757 of 937 epoch 0
# Batch 758 of 937 epoch 0
# Batch 759 of 937 epoch 0
# Batch 760 of 937 epoch 0
# Batch 761 of 937 epoch 0
# Batch 762 of 937 epoch 0
# Batch 763 of 937 epoch 0
# Batch 764 of 937 epoch 0
# Batch 765 of 937 epoch 0
# Batch 766 of 937 epoch 0
# Batch 767 of 937 epoch 0
# Batch 768 of 937 epoch 0
# Batch 769 of 937 epoch 0
# Batch 770 of 937 epoch 0
# Batch 771 of 937 epoch 0
# Batch 772 of 937 epoch 0
# Batch 773 of 937 epoch 0
# Batch 774 of 937 epoch 0
# Batch 775 of 937 epoch 0
# Batch 776 of 937 epoch 0
# Batch 777 of 937 epoch 0
# Batch 778 of 937 epoch 0
# Batch 779 of 937 epoch 0
# Batch 780 of 937 epoch 0
# Batch 781 of 937 epoch 0
# Batch 782 of 937 epoch 0
# Batch 783 of 937 epoch 0
# Batch 784 of 937 epoch 0
# Batch 785 of 937 epoch 0
# Batch 786 of 937 epoch 0
# Batch 787 of 937 epoch 0
# Batch 788 of 937 epoch 0
# Batch 789 of 937 epoch 0
# Batch 790 of 937 epoch 0
# Batch 791 of 937 epoch 0
# Batch 792 of 937 epoch 0
# Batch 793 of 937 epoch 0
# Batch 794 of 937 epoch 0
# Batch 795 of 937 epoch 0
# Batch 796 of 937 epoch 0
# Batch 797 of 937 epoch 0
# Batch 798 of 937 epoch 0
# Batch 799 of 937 epoch 0
# Batch 800 of 937 epoch 0
# Batch 801 of 937 epoch 0
# Batch 802 of 937 epoch 0
# Batch 803 of 937 epoch 0
# Batch 804 of 937 epoch 0
# Batch 805 of 937 epoch 0
# Batch 806 of 937 epoch 0
# Batch 807 of 937 epoch 0
# Batch 808 of 937 epoch 0
# Batch 809 of 937 epoch 0
# Batch 810 of 937 epoch 0
# Batch 811 of 937 epoch 0
# Batch 812 of 937 epoch 0
# Batch 813 of 937 epoch 0
# Batch 814 of 937 epoch 0
# Batch 815 of 937 epoch 0
# Batch 816 of 937 epoch 0
# Batch 817 of 937 epoch 0
# Batch 818 of 937 epoch 0
# Batch 819 of 937 epoch 0
# Batch 820 of 937 epoch 0
# Batch 821 of 937 epoch 0
# Batch 822 of 937 epoch 0
# Batch 823 of 937 epoch 0
# Batch 824 of 937 epoch 0
# Batch 825 of 937 epoch 0
# Batch 826 of 937 epoch 0
# Batch 827 of 937 epoch 0
# Batch 828 of 937 epoch 0
# Batch 829 of 937 epoch 0
# Batch 830 of 937 epoch 0
# Batch 831 of 937 epoch 0
# Batch 832 of 937 epoch 0
# Batch 833 of 937 epoch 0
# Batch 834 of 937 epoch 0
# Batch 835 of 937 epoch 0
# Batch 836 of 937 epoch 0
# Batch 837 of 937 epoch 0
# Batch 838 of 937 epoch 0
# Batch 839 of 937 epoch 0
# Batch 840 of 937 epoch 0
# Batch 841 of 937 epoch 0
# Batch 842 of 937 epoch 0
# Batch 843 of 937 epoch 0
# Batch 844 of 937 epoch 0
# Batch 845 of 937 epoch 0
# Batch 846 of 937 epoch 0
# Batch 847 of 937 epoch 0
# Batch 848 of 937 epoch 0
# Batch 849 of 937 epoch 0
# Batch 850 of 937 epoch 0
# Batch 851 of 937 epoch 0
# Batch 852 of 937 epoch 0
# Batch 853 of 937 epoch 0
# Batch 854 of 937 epoch 0
# Batch 855 of 937 epoch 0
# Batch 856 of 937 epoch 0
# Batch 857 of 937 epoch 0
# Batch 858 of 937 epoch 0
# Batch 859 of 937 epoch 0
# Batch 860 of 937 epoch 0
# Batch 861 of 937 epoch 0
# Batch 862 of 937 epoch 0
# Batch 863 of 937 epoch 0
# Batch 864 of 937 epoch 0
# Batch 865 of 937 epoch 0
# Batch 866 of 937 epoch 0
# Batch 867 of 937 epoch 0
# Batch 868 of 937 epoch 0
# Batch 869 of 937 epoch 0
# Batch 870 of 937 epoch 0
# Batch 871 of 937 epoch 0
# Batch 872 of 937 epoch 0
# Batch 873 of 937 epoch 0
# Batch 874 of 937 epoch 0
# Batch 875 of 937 epoch 0
# Batch 876 of 937 epoch 0
# Batch 877 of 937 epoch 0
# Batch 878 of 937 epoch 0
# Batch 879 of 937 epoch 0
# Batch 880 of 937 epoch 0
# Batch 881 of 937 epoch 0
# Batch 882 of 937 epoch 0
# Batch 883 of 937 epoch 0
# Batch 884 of 937 epoch 0
# Batch 885 of 937 epoch 0
# Batch 886 of 937 epoch 0
# Batch 887 of 937 epoch 0
# Batch 888 of 937 epoch 0
# Batch 889 of 937 epoch 0
# Batch 890 of 937 epoch 0
# Batch 891 of 937 epoch 0
# Batch 892 of 937 epoch 0
# Batch 893 of 937 epoch 0
# Batch 894 of 937 epoch 0
# Batch 895 of 937 epoch 0
# Batch 896 of 937 epoch 0
# Batch 897 of 937 epoch 0
# Batch 898 of 937 epoch 0
# Batch 899 of 937 epoch 0
# Batch 900 of 937 epoch 0
# Batch 901 of 937 epoch 0
# Batch 902 of 937 epoch 0
# Batch 903 of 937 epoch 0
# Batch 904 of 937 epoch 0
# Batch 905 of 937 epoch 0
# Batch 906 of 937 epoch 0
# Batch 907 of 937 epoch 0
# Batch 908 of 937 epoch 0
# Batch 909 of 937 epoch 0
# Batch 910 of 937 epoch 0
# Batch 911 of 937 epoch 0
# Batch 912 of 937 epoch 0
# Batch 913 of 937 epoch 0
# Batch 914 of 937 epoch 0
# Batch 915 of 937 epoch 0
# Batch 916 of 937 epoch 0
# Batch 917 of 937 epoch 0
# Batch 918 of 937 epoch 0
# Batch 919 of 937 epoch 0
# Batch 920 of 937 epoch 0
# Batch 921 of 937 epoch 0
# Batch 922 of 937 epoch 0
# Batch 923 of 937 epoch 0
# Batch 924 of 937 epoch 0
# Batch 925 of 937 epoch 0
# Batch 926 of 937 epoch 0
# Batch 927 of 937 epoch 0
# Batch 928 of 937 epoch 0
# Batch 929 of 937 epoch 0
# Batch 930 of 937 epoch 0
# Batch 931 of 937 epoch 0
# Batch 932 of 937 epoch 0
# Batch 933 of 937 epoch 0
# Batch 934 of 937 epoch 0
# Batch 935 of 937 epoch 0
# Batch 936 of 937 epoch 0
# Batch 0 of 937 epoch 1
# Batch 1 of 937 epoch 1
# Batch 2 of 937 epoch 1
# Batch 3 of 937 epoch 1
# Batch 4 of 937 epoch 1
# Batch 5 of 937 epoch 1
# Batch 6 of 937 epoch 1
# Batch 7 of 937 epoch 1
# Batch 8 of 937 epoch 1
# Batch 9 of 937 epoch 1
# Batch 10 of 937 epoch 1
# Batch 11 of 937 epoch 1
# Batch 12 of 937 epoch 1
# Batch 13 of 937 epoch 1
# Batch 14 of 937 epoch 1
# Batch 15 of 937 epoch 1
# Batch 16 of 937 epoch 1
# Batch 17 of 937 epoch 1
# Batch 18 of 937 epoch 1
# Batch 19 of 937 epoch 1
# Batch 20 of 937 epoch 1
# Batch 21 of 937 epoch 1
# Batch 22 of 937 epoch 1
# Batch 23 of 937 epoch 1
# Batch 24 of 937 epoch 1
# Batch 25 of 937 epoch 1
# Batch 26 of 937 epoch 1
# Batch 27 of 937 epoch 1
# Batch 28 of 937 epoch 1
# Batch 29 of 937 epoch 1
# Batch 30 of 937 epoch 1
# Batch 31 of 937 epoch 1
# Batch 32 of 937 epoch 1
# Batch 33 of 937 epoch 1
# Batch 34 of 937 epoch 1
# Batch 35 of 937 epoch 1
# Batch 36 of 937 epoch 1
# Batch 37 of 937 epoch 1
# Batch 38 of 937 epoch 1
# Batch 39 of 937 epoch 1
# Batch 40 of 937 epoch 1
# Batch 41 of 937 epoch 1
# Batch 42 of 937 epoch 1
# Batch 43 of 937 epoch 1
# Batch 44 of 937 epoch 1
# Batch 45 of 937 epoch 1
# Batch 46 of 937 epoch 1
# Batch 47 of 937 epoch 1
# Batch 48 of 937 epoch 1
# Batch 49 of 937 epoch 1
# Batch 50 of 937 epoch 1
# Batch 51 of 937 epoch 1
# Batch 52 of 937 epoch 1
# Batch 53 of 937 epoch 1
# Batch 54 of 937 epoch 1
# Batch 55 of 937 epoch 1
# Batch 56 of 937 epoch 1
# Batch 57 of 937 epoch 1
# Batch 58 of 937 epoch 1
# Batch 59 of 937 epoch 1
# Batch 60 of 937 epoch 1
# Batch 61 of 937 epoch 1
# Batch 62 of 937 epoch 1
# Batch 63 of 937 epoch 1
# Batch 64 of 937 epoch 1
# Batch 65 of 937 epoch 1
# Batch 66 of 937 epoch 1
# Batch 67 of 937 epoch 1
# Batch 68 of 937 epoch 1
# Batch 69 of 937 epoch 1
# Batch 70 of 937 epoch 1
# Batch 71 of 937 epoch 1
# Batch 72 of 937 epoch 1
# Batch 73 of 937 epoch 1
# Batch 74 of 937 epoch 1
# Batch 75 of 937 epoch 1
# Batch 76 of 937 epoch 1
# Batch 77 of 937 epoch 1
# Batch 78 of 937 epoch 1
# Batch 79 of 937 epoch 1
# Batch 80 of 937 epoch 1
# Batch 81 of 937 epoch 1
# Batch 82 of 937 epoch 1
# Batch 83 of 937 epoch 1
# Batch 84 of 937 epoch 1
# Batch 85 of 937 epoch 1
# Batch 86 of 937 epoch 1
# Batch 87 of 937 epoch 1
# Batch 88 of 937 epoch 1
# Batch 89 of 937 epoch 1
# Batch 90 of 937 epoch 1
# Batch 91 of 937 epoch 1
# Batch 92 of 937 epoch 1
# Batch 93 of 937 epoch 1
# Batch 94 of 937 epoch 1
# Batch 95 of 937 epoch 1
# Batch 96 of 937 epoch 1
# Batch 97 of 937 epoch 1
# Batch 98 of 937 epoch 1
# Batch 99 of 937 epoch 1
# Batch 100 of 937 epoch 1
# Batch 101 of 937 epoch 1
# Batch 102 of 937 epoch 1
# Batch 103 of 937 epoch 1
# Batch 104 of 937 epoch 1
# Batch 105 of 937 epoch 1
# Batch 106 of 937 epoch 1
# Batch 107 of 937 epoch 1
# Batch 108 of 937 epoch 1
# Batch 109 of 937 epoch 1
# Batch 110 of 937 epoch 1
# Batch 111 of 937 epoch 1
# Batch 112 of 937 epoch 1
# Batch 113 of 937 epoch 1
# Batch 114 of 937 epoch 1
# Batch 115 of 937 epoch 1
# Batch 116 of 937 epoch 1
# Batch 117 of 937 epoch 1
# Batch 118 of 937 epoch 1
# Batch 119 of 937 epoch 1
# Batch 120 of 937 epoch 1
# Batch 121 of 937 epoch 1
# Batch 122 of 937 epoch 1
# Batch 123 of 937 epoch 1
# Batch 124 of 937 epoch 1
# Batch 125 of 937 epoch 1
# Batch 126 of 937 epoch 1
# Batch 127 of 937 epoch 1
# Batch 128 of 937 epoch 1
# Batch 129 of 937 epoch 1
# Batch 130 of 937 epoch 1
# Batch 131 of 937 epoch 1
# Batch 132 of 937 epoch 1
# Batch 133 of 937 epoch 1
# Batch 134 of 937 epoch 1
# Batch 135 of 937 epoch 1
# Batch 136 of 937 epoch 1
# Batch 137 of 937 epoch 1
# Batch 138 of 937 epoch 1
# Batch 139 of 937 epoch 1
# Batch 140 of 937 epoch 1
# Batch 141 of 937 epoch 1
# Batch 142 of 937 epoch 1
# Batch 143 of 937 epoch 1
# Batch 144 of 937 epoch 1
# Batch 145 of 937 epoch 1
# Batch 146 of 937 epoch 1
# Batch 147 of 937 epoch 1
# Batch 148 of 937 epoch 1
# Batch 149 of 937 epoch 1
# Batch 150 of 937 epoch 1
# Batch 151 of 937 epoch 1
# Batch 152 of 937 epoch 1
# Batch 153 of 937 epoch 1
# Batch 154 of 937 epoch 1
# Batch 155 of 937 epoch 1
# Batch 156 of 937 epoch 1
# Batch 157 of 937 epoch 1
# Batch 158 of 937 epoch 1
# Batch 159 of 937 epoch 1
# Batch 160 of 937 epoch 1
# Batch 161 of 937 epoch 1
# Batch 162 of 937 epoch 1
# Batch 163 of 937 epoch 1
# Batch 164 of 937 epoch 1
# Batch 165 of 937 epoch 1
# Batch 166 of 937 epoch 1
# Batch 167 of 937 epoch 1
# Batch 168 of 937 epoch 1
# Batch 169 of 937 epoch 1
# Batch 170 of 937 epoch 1
# Batch 171 of 937 epoch 1
# Batch 172 of 937 epoch 1
# Batch 173 of 937 epoch 1
# Batch 174 of 937 epoch 1
# Batch 175 of 937 epoch 1
# Batch 176 of 937 epoch 1
# Batch 177 of 937 epoch 1
# Batch 178 of 937 epoch 1
# Batch 179 of 937 epoch 1
# Batch 180 of 937 epoch 1
# Batch 181 of 937 epoch 1
# Batch 182 of 937 epoch 1
# Batch 183 of 937 epoch 1
# Batch 184 of 937 epoch 1
# Batch 185 of 937 epoch 1
# Batch 186 of 937 epoch 1
# Batch 187 of 937 epoch 1
# Batch 188 of 937 epoch 1
# Batch 189 of 937 epoch 1
# Batch 190 of 937 epoch 1
# Batch 191 of 937 epoch 1
# Batch 192 of 937 epoch 1
# Batch 193 of 937 epoch 1
# Batch 194 of 937 epoch 1
# Batch 195 of 937 epoch 1
# Batch 196 of 937 epoch 1
# Batch 197 of 937 epoch 1
# Batch 198 of 937 epoch 1
# Batch 199 of 937 epoch 1
# Batch 200 of 937 epoch 1
# Batch 201 of 937 epoch 1
# Batch 202 of 937 epoch 1
# Batch 203 of 937 epoch 1
# Batch 204 of 937 epoch 1
# Batch 205 of 937 epoch 1
# Batch 206 of 937 epoch 1
# Batch 207 of 937 epoch 1
# Batch 208 of 937 epoch 1
# Batch 209 of 937 epoch 1
# Batch 210 of 937 epoch 1
# Batch 211 of 937 epoch 1
# Batch 212 of 937 epoch 1
# Batch 213 of 937 epoch 1
# Batch 214 of 937 epoch 1
# Batch 215 of 937 epoch 1
# Batch 216 of 937 epoch 1
# Batch 217 of 937 epoch 1
# Batch 218 of 937 epoch 1
# Batch 219 of 937 epoch 1
# Batch 220 of 937 epoch 1
# Batch 221 of 937 epoch 1
# Batch 222 of 937 epoch 1
# Batch 223 of 937 epoch 1
# Batch 224 of 937 epoch 1
# Batch 225 of 937 epoch 1
# Batch 226 of 937 epoch 1
# Batch 227 of 937 epoch 1
# Batch 228 of 937 epoch 1
# Batch 229 of 937 epoch 1
# Batch 230 of 937 epoch 1
# Batch 231 of 937 epoch 1
# Batch 232 of 937 epoch 1
# Batch 233 of 937 epoch 1
# Batch 234 of 937 epoch 1
# Batch 235 of 937 epoch 1
# Batch 236 of 937 epoch 1
# Batch 237 of 937 epoch 1
# Batch 238 of 937 epoch 1
# Batch 239 of 937 epoch 1
# Batch 240 of 937 epoch 1
# Batch 241 of 937 epoch 1
# Batch 242 of 937 epoch 1
# Batch 243 of 937 epoch 1
# Batch 244 of 937 epoch 1
# Batch 245 of 937 epoch 1
# Batch 246 of 937 epoch 1
# Batch 247 of 937 epoch 1
# Batch 248 of 937 epoch 1
# Batch 249 of 937 epoch 1
# Batch 250 of 937 epoch 1
# Batch 251 of 937 epoch 1
# Batch 252 of 937 epoch 1
# Batch 253 of 937 epoch 1
# Batch 254 of 937 epoch 1
# Batch 255 of 937 epoch 1
# Batch 256 of 937 epoch 1
# Batch 257 of 937 epoch 1
# Batch 258 of 937 epoch 1
# Batch 259 of 937 epoch 1
# Batch 260 of 937 epoch 1
# Batch 261 of 937 epoch 1
# Batch 262 of 937 epoch 1
# Batch 263 of 937 epoch 1
# Batch 264 of 937 epoch 1
# Batch 265 of 937 epoch 1
# Batch 266 of 937 epoch 1
# Batch 267 of 937 epoch 1
# Batch 268 of 937 epoch 1
# Batch 269 of 937 epoch 1
# Batch 270 of 937 epoch 1
# Batch 271 of 937 epoch 1
# Batch 272 of 937 epoch 1
# Batch 273 of 937 epoch 1
# Batch 274 of 937 epoch 1
# Batch 275 of 937 epoch 1
# Batch 276 of 937 epoch 1
# Batch 277 of 937 epoch 1
# Batch 278 of 937 epoch 1
# Batch 279 of 937 epoch 1
# Batch 280 of 937 epoch 1
# Batch 281 of 937 epoch 1
# Batch 282 of 937 epoch 1
# Batch 283 of 937 epoch 1
# Batch 284 of 937 epoch 1
# Batch 285 of 937 epoch 1
# Batch 286 of 937 epoch 1
# Batch 287 of 937 epoch 1
# Batch 288 of 937 epoch 1
# Batch 289 of 937 epoch 1
# Batch 290 of 937 epoch 1
# Batch 291 of 937 epoch 1
# Batch 292 of 937 epoch 1
# Batch 293 of 937 epoch 1
# Batch 294 of 937 epoch 1
# Batch 295 of 937 epoch 1
# Batch 296 of 937 epoch 1
# Batch 297 of 937 epoch 1
# Batch 298 of 937 epoch 1
# Batch 299 of 937 epoch 1
# Batch 300 of 937 epoch 1
# Batch 301 of 937 epoch 1
# Batch 302 of 937 epoch 1
# Batch 303 of 937 epoch 1
# Batch 304 of 937 epoch 1
# Batch 305 of 937 epoch 1
# Batch 306 of 937 epoch 1
# Batch 307 of 937 epoch 1
# Batch 308 of 937 epoch 1
# Batch 309 of 937 epoch 1
# Batch 310 of 937 epoch 1
# Batch 311 of 937 epoch 1
# Batch 312 of 937 epoch 1
# Batch 313 of 937 epoch 1
# Batch 314 of 937 epoch 1
# Batch 315 of 937 epoch 1
# Batch 316 of 937 epoch 1
# Batch 317 of 937 epoch 1
# Batch 318 of 937 epoch 1
# Batch 319 of 937 epoch 1
# Batch 320 of 937 epoch 1
# Batch 321 of 937 epoch 1
# Batch 322 of 937 epoch 1
# Batch 323 of 937 epoch 1
# Batch 324 of 937 epoch 1
# Batch 325 of 937 epoch 1
# Batch 326 of 937 epoch 1
# Batch 327 of 937 epoch 1
# Batch 328 of 937 epoch 1
# Batch 329 of 937 epoch 1
# Batch 330 of 937 epoch 1
# Batch 331 of 937 epoch 1
# Batch 332 of 937 epoch 1
# Batch 333 of 937 epoch 1
# Batch 334 of 937 epoch 1
# Batch 335 of 937 epoch 1
# Batch 336 of 937 epoch 1
# Batch 337 of 937 epoch 1
# Batch 338 of 937 epoch 1
# Batch 339 of 937 epoch 1
# Batch 340 of 937 epoch 1
# Batch 341 of 937 epoch 1
# Batch 342 of 937 epoch 1
# Batch 343 of 937 epoch 1
# Batch 344 of 937 epoch 1
# Batch 345 of 937 epoch 1
# Batch 346 of 937 epoch 1
# Batch 347 of 937 epoch 1
# Batch 348 of 937 epoch 1
# Batch 349 of 937 epoch 1
# Batch 350 of 937 epoch 1
# Batch 351 of 937 epoch 1
# Batch 352 of 937 epoch 1
# Batch 353 of 937 epoch 1
# Batch 354 of 937 epoch 1
# Batch 355 of 937 epoch 1
# Batch 356 of 937 epoch 1
# Batch 357 of 937 epoch 1
# Batch 358 of 937 epoch 1
# Batch 359 of 937 epoch 1
# Batch 360 of 937 epoch 1
# Batch 361 of 937 epoch 1
# Batch 362 of 937 epoch 1
# Batch 363 of 937 epoch 1
# Batch 364 of 937 epoch 1
# Batch 365 of 937 epoch 1
# Batch 366 of 937 epoch 1
# Batch 367 of 937 epoch 1
# Batch 368 of 937 epoch 1
# Batch 369 of 937 epoch 1
# Batch 370 of 937 epoch 1
# Batch 371 of 937 epoch 1
# Batch 372 of 937 epoch 1
# Batch 373 of 937 epoch 1
# Batch 374 of 937 epoch 1
# Batch 375 of 937 epoch 1
# Batch 376 of 937 epoch 1
# Batch 377 of 937 epoch 1
# Batch 378 of 937 epoch 1
# Batch 379 of 937 epoch 1
# Batch 380 of 937 epoch 1
# Batch 381 of 937 epoch 1
# Batch 382 of 937 epoch 1
# Batch 383 of 937 epoch 1
# Batch 384 of 937 epoch 1
# Batch 385 of 937 epoch 1
# Batch 386 of 937 epoch 1
# Batch 387 of 937 epoch 1
# Batch 388 of 937 epoch 1
# Batch 389 of 937 epoch 1
# Batch 390 of 937 epoch 1
# Batch 391 of 937 epoch 1
# Batch 392 of 937 epoch 1
# Batch 393 of 937 epoch 1
# Batch 394 of 937 epoch 1
# Batch 395 of 937 epoch 1
# Batch 396 of 937 epoch 1
# Batch 397 of 937 epoch 1
# Batch 398 of 937 epoch 1
# Batch 399 of 937 epoch 1
# Batch 400 of 937 epoch 1
# Batch 401 of 937 epoch 1
# Batch 402 of 937 epoch 1
# Batch 403 of 937 epoch 1
# Batch 404 of 937 epoch 1
# Batch 405 of 937 epoch 1
# Batch 406 of 937 epoch 1
# Batch 407 of 937 epoch 1
# Batch 408 of 937 epoch 1
# Batch 409 of 937 epoch 1
# Batch 410 of 937 epoch 1
# Batch 411 of 937 epoch 1
# Batch 412 of 937 epoch 1
# Batch 413 of 937 epoch 1
# Batch 414 of 937 epoch 1
# Batch 415 of 937 epoch 1
# Batch 416 of 937 epoch 1
# Batch 417 of 937 epoch 1
# Batch 418 of 937 epoch 1
# Batch 419 of 937 epoch 1
# Batch 420 of 937 epoch 1
# Batch 421 of 937 epoch 1
# Batch 422 of 937 epoch 1
# Batch 423 of 937 epoch 1
# Batch 424 of 937 epoch 1
# Batch 425 of 937 epoch 1
# Batch 426 of 937 epoch 1
# Batch 427 of 937 epoch 1
# Batch 428 of 937 epoch 1
# Batch 429 of 937 epoch 1
# Batch 430 of 937 epoch 1
# Batch 431 of 937 epoch 1
# Batch 432 of 937 epoch 1
# Batch 433 of 937 epoch 1
# Batch 434 of 937 epoch 1
# Batch 435 of 937 epoch 1
# Batch 436 of 937 epoch 1
# Batch 437 of 937 epoch 1
# Batch 438 of 937 epoch 1
# Batch 439 of 937 epoch 1
# Batch 440 of 937 epoch 1
# Batch 441 of 937 epoch 1
# Batch 442 of 937 epoch 1
# Batch 443 of 937 epoch 1
# Batch 444 of 937 epoch 1
# Batch 445 of 937 epoch 1
# Batch 446 of 937 epoch 1
# Batch 447 of 937 epoch 1
# Batch 448 of 937 epoch 1
# Batch 449 of 937 epoch 1
# Batch 450 of 937 epoch 1
# Batch 451 of 937 epoch 1
# Batch 452 of 937 epoch 1
# Batch 453 of 937 epoch 1
# Batch 454 of 937 epoch 1
# Batch 455 of 937 epoch 1
# Batch 456 of 937 epoch 1
# Batch 457 of 937 epoch 1
# Batch 458 of 937 epoch 1
# Batch 459 of 937 epoch 1
# Batch 460 of 937 epoch 1
# Batch 461 of 937 epoch 1
# Batch 462 of 937 epoch 1
# Batch 463 of 937 epoch 1
# Batch 464 of 937 epoch 1
# Batch 465 of 937 epoch 1
# Batch 466 of 937 epoch 1
# Batch 467 of 937 epoch 1
# Batch 468 of 937 epoch 1
# Batch 469 of 937 epoch 1
# Batch 470 of 937 epoch 1
# Batch 471 of 937 epoch 1
# Batch 472 of 937 epoch 1
# Batch 473 of 937 epoch 1
# Batch 474 of 937 epoch 1
# Batch 475 of 937 epoch 1
# Batch 476 of 937 epoch 1
# Batch 477 of 937 epoch 1
# Batch 478 of 937 epoch 1
# Batch 479 of 937 epoch 1
# Batch 480 of 937 epoch 1
# Batch 481 of 937 epoch 1
# Batch 482 of 937 epoch 1
# Batch 483 of 937 epoch 1
# Batch 484 of 937 epoch 1
# Batch 485 of 937 epoch 1
# Batch 486 of 937 epoch 1
# Batch 487 of 937 epoch 1
# Batch 488 of 937 epoch 1
# Batch 489 of 937 epoch 1
# Batch 490 of 937 epoch 1
# Batch 491 of 937 epoch 1
# Batch 492 of 937 epoch 1
# Batch 493 of 937 epoch 1
# Batch 494 of 937 epoch 1
# Batch 495 of 937 epoch 1
# Batch 496 of 937 epoch 1
# Batch 497 of 937 epoch 1
# Batch 498 of 937 epoch 1
# Batch 499 of 937 epoch 1
# Batch 500 of 937 epoch 1
# Batch 501 of 937 epoch 1
# Batch 502 of 937 epoch 1
# Batch 503 of 937 epoch 1
# Batch 504 of 937 epoch 1
# Batch 505 of 937 epoch 1
# Batch 506 of 937 epoch 1
# Batch 507 of 937 epoch 1
# Batch 508 of 937 epoch 1
# Batch 509 of 937 epoch 1
# Batch 510 of 937 epoch 1
# Batch 511 of 937 epoch 1
# Batch 512 of 937 epoch 1
# Batch 513 of 937 epoch 1
# Batch 514 of 937 epoch 1
# Batch 515 of 937 epoch 1
# Batch 516 of 937 epoch 1
# Batch 517 of 937 epoch 1
# Batch 518 of 937 epoch 1
# Batch 519 of 937 epoch 1
# Batch 520 of 937 epoch 1
# Batch 521 of 937 epoch 1
# Batch 522 of 937 epoch 1
# Batch 523 of 937 epoch 1
# Batch 524 of 937 epoch 1
# Batch 525 of 937 epoch 1
# Batch 526 of 937 epoch 1
# Batch 527 of 937 epoch 1
# Batch 528 of 937 epoch 1
# Batch 529 of 937 epoch 1
# Batch 530 of 937 epoch 1
# Batch 531 of 937 epoch 1
# Batch 532 of 937 epoch 1
# Batch 533 of 937 epoch 1
# Batch 534 of 937 epoch 1
# Batch 535 of 937 epoch 1
# Batch 536 of 937 epoch 1
# Batch 537 of 937 epoch 1
# Batch 538 of 937 epoch 1
# Batch 539 of 937 epoch 1
# Batch 540 of 937 epoch 1
# Batch 541 of 937 epoch 1
# Batch 542 of 937 epoch 1
# Batch 543 of 937 epoch 1
# Batch 544 of 937 epoch 1
# Batch 545 of 937 epoch 1
# Batch 546 of 937 epoch 1
# Batch 547 of 937 epoch 1
# Batch 548 of 937 epoch 1
# Batch 549 of 937 epoch 1
# Batch 550 of 937 epoch 1
# Batch 551 of 937 epoch 1
# Batch 552 of 937 epoch 1
# Batch 553 of 937 epoch 1
# Batch 554 of 937 epoch 1
# Batch 555 of 937 epoch 1
# Batch 556 of 937 epoch 1
# Batch 557 of 937 epoch 1
# Batch 558 of 937 epoch 1
# Batch 559 of 937 epoch 1
# Batch 560 of 937 epoch 1
# Batch 561 of 937 epoch 1
# Batch 562 of 937 epoch 1
# Batch 563 of 937 epoch 1
# Batch 564 of 937 epoch 1
# Batch 565 of 937 epoch 1
# Batch 566 of 937 epoch 1
# Batch 567 of 937 epoch 1
# Batch 568 of 937 epoch 1
# Batch 569 of 937 epoch 1
# Batch 570 of 937 epoch 1
# Batch 571 of 937 epoch 1
# Batch 572 of 937 epoch 1
# Batch 573 of 937 epoch 1
# Batch 574 of 937 epoch 1
# Batch 575 of 937 epoch 1
# Batch 576 of 937 epoch 1
# Batch 577 of 937 epoch 1
# Batch 578 of 937 epoch 1
# Batch 579 of 937 epoch 1
# Batch 580 of 937 epoch 1
# Batch 581 of 937 epoch 1
# Batch 582 of 937 epoch 1
# Batch 583 of 937 epoch 1
# Batch 584 of 937 epoch 1
# Batch 585 of 937 epoch 1
# Batch 586 of 937 epoch 1
# Batch 587 of 937 epoch 1
# Batch 588 of 937 epoch 1
# Batch 589 of 937 epoch 1
# Batch 590 of 937 epoch 1
# Batch 591 of 937 epoch 1
# Batch 592 of 937 epoch 1
# Batch 593 of 937 epoch 1
# Batch 594 of 937 epoch 1
# Batch 595 of 937 epoch 1
# Batch 596 of 937 epoch 1
# Batch 597 of 937 epoch 1
# Batch 598 of 937 epoch 1
# Batch 599 of 937 epoch 1
# Batch 600 of 937 epoch 1
# Batch 601 of 937 epoch 1
# Batch 602 of 937 epoch 1
# Batch 603 of 937 epoch 1
# Batch 604 of 937 epoch 1
# Batch 605 of 937 epoch 1
# Batch 606 of 937 epoch 1
# Batch 607 of 937 epoch 1
# Batch 608 of 937 epoch 1
# Batch 609 of 937 epoch 1
# Batch 610 of 937 epoch 1
# Batch 611 of 937 epoch 1
# Batch 612 of 937 epoch 1
# Batch 613 of 937 epoch 1
# Batch 614 of 937 epoch 1
# Batch 615 of 937 epoch 1
# Batch 616 of 937 epoch 1
# Batch 617 of 937 epoch 1
# Batch 618 of 937 epoch 1
# Batch 619 of 937 epoch 1
# Batch 620 of 937 epoch 1
# Batch 621 of 937 epoch 1
# Batch 622 of 937 epoch 1
# Batch 623 of 937 epoch 1
# Batch 624 of 937 epoch 1
# Batch 625 of 937 epoch 1
# Batch 626 of 937 epoch 1
# Batch 627 of 937 epoch 1
# Batch 628 of 937 epoch 1
# Batch 629 of 937 epoch 1
# Batch 630 of 937 epoch 1
# Batch 631 of 937 epoch 1
# Batch 632 of 937 epoch 1
# Batch 633 of 937 epoch 1
# Batch 634 of 937 epoch 1
# Batch 635 of 937 epoch 1
# Batch 636 of 937 epoch 1
# Batch 637 of 937 epoch 1
# Batch 638 of 937 epoch 1
# Batch 639 of 937 epoch 1
# Batch 640 of 937 epoch 1
# Batch 641 of 937 epoch 1
# Batch 642 of 937 epoch 1
# Batch 643 of 937 epoch 1
# Batch 644 of 937 epoch 1
# Batch 645 of 937 epoch 1
# Batch 646 of 937 epoch 1
# Batch 647 of 937 epoch 1
# Batch 648 of 937 epoch 1
# Batch 649 of 937 epoch 1
# Batch 650 of 937 epoch 1
# Batch 651 of 937 epoch 1
# Batch 652 of 937 epoch 1
# Batch 653 of 937 epoch 1
# Batch 654 of 937 epoch 1
# Batch 655 of 937 epoch 1
# Batch 656 of 937 epoch 1
# Batch 657 of 937 epoch 1
# Batch 658 of 937 epoch 1
# Batch 659 of 937 epoch 1
# Batch 660 of 937 epoch 1
# Batch 661 of 937 epoch 1
# Batch 662 of 937 epoch 1
# Batch 663 of 937 epoch 1
# Batch 664 of 937 epoch 1
# Batch 665 of 937 epoch 1
# Batch 666 of 937 epoch 1
# Batch 667 of 937 epoch 1
# Batch 668 of 937 epoch 1
# Batch 669 of 937 epoch 1
# Batch 670 of 937 epoch 1
# Batch 671 of 937 epoch 1
# Batch 672 of 937 epoch 1
# Batch 673 of 937 epoch 1
# Batch 674 of 937 epoch 1
# Batch 675 of 937 epoch 1
# Batch 676 of 937 epoch 1
# Batch 677 of 937 epoch 1
# Batch 678 of 937 epoch 1
# Batch 679 of 937 epoch 1
# Batch 680 of 937 epoch 1
# Batch 681 of 937 epoch 1
# Batch 682 of 937 epoch 1
# Batch 683 of 937 epoch 1
# Batch 684 of 937 epoch 1
# Batch 685 of 937 epoch 1
# Batch 686 of 937 epoch 1
# Batch 687 of 937 epoch 1
# Batch 688 of 937 epoch 1
# Batch 689 of 937 epoch 1
# Batch 690 of 937 epoch 1
# Batch 691 of 937 epoch 1
# Batch 692 of 937 epoch 1
# Batch 693 of 937 epoch 1
# Batch 694 of 937 epoch 1
# Batch 695 of 937 epoch 1
# Batch 696 of 937 epoch 1
# Batch 697 of 937 epoch 1
# Batch 698 of 937 epoch 1
# Batch 699 of 937 epoch 1
# Batch 700 of 937 epoch 1
# Batch 701 of 937 epoch 1
# Batch 702 of 937 epoch 1
# Batch 703 of 937 epoch 1
# Batch 704 of 937 epoch 1
# Batch 705 of 937 epoch 1
# Batch 706 of 937 epoch 1
# Batch 707 of 937 epoch 1
# Batch 708 of 937 epoch 1
# Batch 709 of 937 epoch 1
# Batch 710 of 937 epoch 1
# Batch 711 of 937 epoch 1
# Batch 712 of 937 epoch 1
# Batch 713 of 937 epoch 1
# Batch 714 of 937 epoch 1
# Batch 715 of 937 epoch 1
# Batch 716 of 937 epoch 1
# Batch 717 of 937 epoch 1
# Batch 718 of 937 epoch 1
# Batch 719 of 937 epoch 1
# Batch 720 of 937 epoch 1
# Batch 721 of 937 epoch 1
# Batch 722 of 937 epoch 1
# Batch 723 of 937 epoch 1
# Batch 724 of 937 epoch 1
# Batch 725 of 937 epoch 1
# Batch 726 of 937 epoch 1
# Batch 727 of 937 epoch 1
# Batch 728 of 937 epoch 1
# Batch 729 of 937 epoch 1
# Batch 730 of 937 epoch 1
# Batch 731 of 937 epoch 1
# Batch 732 of 937 epoch 1
# Batch 733 of 937 epoch 1
# Batch 734 of 937 epoch 1
# Batch 735 of 937 epoch 1
# Batch 736 of 937 epoch 1
# Batch 737 of 937 epoch 1
# Batch 738 of 937 epoch 1
# Batch 739 of 937 epoch 1
# Batch 740 of 937 epoch 1
# Batch 741 of 937 epoch 1
# Batch 742 of 937 epoch 1
# Batch 743 of 937 epoch 1
# Batch 744 of 937 epoch 1
# Batch 745 of 937 epoch 1
# Batch 746 of 937 epoch 1
# Batch 747 of 937 epoch 1
# Batch 748 of 937 epoch 1
# Batch 749 of 937 epoch 1
# Batch 750 of 937 epoch 1
# Batch 751 of 937 epoch 1
# Batch 752 of 937 epoch 1
# Batch 753 of 937 epoch 1
# Batch 754 of 937 epoch 1
# Batch 755 of 937 epoch 1
# Batch 756 of 937 epoch 1
# Batch 757 of 937 epoch 1
# Batch 758 of 937 epoch 1
# Batch 759 of 937 epoch 1
# Batch 760 of 937 epoch 1
# Batch 761 of 937 epoch 1
# Batch 762 of 937 epoch 1
# Batch 763 of 937 epoch 1
# Batch 764 of 937 epoch 1
# Batch 765 of 937 epoch 1
# Batch 766 of 937 epoch 1
# Batch 767 of 937 epoch 1
# Batch 768 of 937 epoch 1
# Batch 769 of 937 epoch 1
# Batch 770 of 937 epoch 1
# Batch 771 of 937 epoch 1
# Batch 772 of 937 epoch 1
# Batch 773 of 937 epoch 1
# Batch 774 of 937 epoch 1
# Batch 775 of 937 epoch 1
# Batch 776 of 937 epoch 1
# Batch 777 of 937 epoch 1
# Batch 778 of 937 epoch 1
# Batch 779 of 937 epoch 1
# Batch 780 of 937 epoch 1
# Batch 781 of 937 epoch 1
# Batch 782 of 937 epoch 1
# Batch 783 of 937 epoch 1
# Batch 784 of 937 epoch 1
# Batch 785 of 937 epoch 1
# Batch 786 of 937 epoch 1
# Batch 787 of 937 epoch 1
# Batch 788 of 937 epoch 1
# Batch 789 of 937 epoch 1
# Batch 790 of 937 epoch 1
# Batch 791 of 937 epoch 1
# Batch 792 of 937 epoch 1
# Batch 793 of 937 epoch 1
# Batch 794 of 937 epoch 1
# Batch 795 of 937 epoch 1
# Batch 796 of 937 epoch 1
# Batch 797 of 937 epoch 1
# Batch 798 of 937 epoch 1
# Batch 799 of 937 epoch 1
# Batch 800 of 937 epoch 1
# Batch 801 of 937 epoch 1
# Batch 802 of 937 epoch 1
# Batch 803 of 937 epoch 1
# Batch 804 of 937 epoch 1
# Batch 805 of 937 epoch 1
# Batch 806 of 937 epoch 1
# Batch 807 of 937 epoch 1
# Batch 808 of 937 epoch 1
# Batch 809 of 937 epoch 1
# Batch 810 of 937 epoch 1
# Batch 811 of 937 epoch 1
# Batch 812 of 937 epoch 1
# Batch 813 of 937 epoch 1
# Batch 814 of 937 epoch 1
# Batch 815 of 937 epoch 1
# Batch 816 of 937 epoch 1
# Batch 817 of 937 epoch 1
# Batch 818 of 937 epoch 1
# Batch 819 of 937 epoch 1
# Batch 820 of 937 epoch 1
# Batch 821 of 937 epoch 1
# Batch 822 of 937 epoch 1
# Batch 823 of 937 epoch 1
# Batch 824 of 937 epoch 1
# Batch 825 of 937 epoch 1
# Batch 826 of 937 epoch 1
# Batch 827 of 937 epoch 1
# Batch 828 of 937 epoch 1
# Batch 829 of 937 epoch 1
# Batch 830 of 937 epoch 1
# Batch 831 of 937 epoch 1
# Batch 832 of 937 epoch 1
# Batch 833 of 937 epoch 1
# Batch 834 of 937 epoch 1
# Batch 835 of 937 epoch 1
# Batch 836 of 937 epoch 1
# Batch 837 of 937 epoch 1
# Batch 838 of 937 epoch 1
# Batch 839 of 937 epoch 1
# Batch 840 of 937 epoch 1
# Batch 841 of 937 epoch 1
# Batch 842 of 937 epoch 1
# Batch 843 of 937 epoch 1
# Batch 844 of 937 epoch 1
# Batch 845 of 937 epoch 1
# Batch 846 of 937 epoch 1
# Batch 847 of 937 epoch 1
# Batch 848 of 937 epoch 1
# Batch 849 of 937 epoch 1
# Batch 850 of 937 epoch 1
# Batch 851 of 937 epoch 1
# Batch 852 of 937 epoch 1
# Batch 853 of 937 epoch 1
# Batch 854 of 937 epoch 1
# Batch 855 of 937 epoch 1
# Batch 856 of 937 epoch 1
# Batch 857 of 937 epoch 1
# Batch 858 of 937 epoch 1
# Batch 859 of 937 epoch 1
# Batch 860 of 937 epoch 1
# Batch 861 of 937 epoch 1
# Batch 862 of 937 epoch 1
# Batch 863 of 937 epoch 1
# Batch 864 of 937 epoch 1
# Batch 865 of 937 epoch 1
# Batch 866 of 937 epoch 1
# Batch 867 of 937 epoch 1
# Batch 868 of 937 epoch 1
# Batch 869 of 937 epoch 1
# Batch 870 of 937 epoch 1
# Batch 871 of 937 epoch 1
# Batch 872 of 937 epoch 1
# Batch 873 of 937 epoch 1
# Batch 874 of 937 epoch 1
# Batch 875 of 937 epoch 1
# Batch 876 of 937 epoch 1
# Batch 877 of 937 epoch 1
# Batch 878 of 937 epoch 1
# Batch 879 of 937 epoch 1
# Batch 880 of 937 epoch 1
# Batch 881 of 937 epoch 1
# Batch 882 of 937 epoch 1
# Batch 883 of 937 epoch 1
# Batch 884 of 937 epoch 1
# Batch 885 of 937 epoch 1
# Batch 886 of 937 epoch 1
# Batch 887 of 937 epoch 1
# Batch 888 of 937 epoch 1
# Batch 889 of 937 epoch 1
# Batch 890 of 937 epoch 1
# Batch 891 of 937 epoch 1
# Batch 892 of 937 epoch 1
# Batch 893 of 937 epoch 1
# Batch 894 of 937 epoch 1
# Batch 895 of 937 epoch 1
# Batch 896 of 937 epoch 1
# Batch 897 of 937 epoch 1
# Batch 898 of 937 epoch 1
# Batch 899 of 937 epoch 1
# Batch 900 of 937 epoch 1
# Batch 901 of 937 epoch 1
# Batch 902 of 937 epoch 1
# Batch 903 of 937 epoch 1
# Batch 904 of 937 epoch 1
# Batch 905 of 937 epoch 1
# Batch 906 of 937 epoch 1
# Batch 907 of 937 epoch 1
# Batch 908 of 937 epoch 1
# Batch 909 of 937 epoch 1
# Batch 910 of 937 epoch 1
# Batch 911 of 937 epoch 1
# Batch 912 of 937 epoch 1
# Batch 913 of 937 epoch 1
# Batch 914 of 937 epoch 1
# Batch 915 of 937 epoch 1
# Batch 916 of 937 epoch 1
# Batch 917 of 937 epoch 1
# Batch 918 of 937 epoch 1
# Batch 919 of 937 epoch 1
# Batch 920 of 937 epoch 1
# Batch 921 of 937 epoch 1
# Batch 922 of 937 epoch 1
# Batch 923 of 937 epoch 1
# Batch 924 of 937 epoch 1
# Batch 925 of 937 epoch 1
# Batch 926 of 937 epoch 1
# Batch 927 of 937 epoch 1
# Batch 928 of 937 epoch 1
# Batch 929 of 937 epoch 1
# Batch 930 of 937 epoch 1
# Batch 931 of 937 epoch 1
# Batch 932 of 937 epoch 1
# Batch 933 of 937 epoch 1
# Batch 934 of 937 epoch 1
# Batch 935 of 937 epoch 1
# Batch 936 of 937 epoch 1
# Batch 0 of 937 epoch 2
# Batch 1 of 937 epoch 2
# Batch 2 of 937 epoch 2
# Batch 3 of 937 epoch 2
# Batch 4 of 937 epoch 2
# Batch 5 of 937 epoch 2
# Batch 6 of 937 epoch 2
# Batch 7 of 937 epoch 2
# Batch 8 of 937 epoch 2
# Batch 9 of 937 epoch 2
# Batch 10 of 937 epoch 2
# Batch 11 of 937 epoch 2
# Batch 12 of 937 epoch 2
# Batch 13 of 937 epoch 2
# Batch 14 of 937 epoch 2
# Batch 15 of 937 epoch 2
# Batch 16 of 937 epoch 2
# Batch 17 of 937 epoch 2
# Batch 18 of 937 epoch 2
# Batch 19 of 937 epoch 2
# Batch 20 of 937 epoch 2
# Batch 21 of 937 epoch 2
# Batch 22 of 937 epoch 2
# Batch 23 of 937 epoch 2
# Batch 24 of 937 epoch 2
# Batch 25 of 937 epoch 2
# Batch 26 of 937 epoch 2
# Batch 27 of 937 epoch 2
# Batch 28 of 937 epoch 2
# Batch 29 of 937 epoch 2
# Batch 30 of 937 epoch 2
# Batch 31 of 937 epoch 2
# Batch 32 of 937 epoch 2
# Batch 33 of 937 epoch 2
# Batch 34 of 937 epoch 2
# Batch 35 of 937 epoch 2
# Batch 36 of 937 epoch 2
# Batch 37 of 937 epoch 2
# Batch 38 of 937 epoch 2
# Batch 39 of 937 epoch 2
# Batch 40 of 937 epoch 2
# Batch 41 of 937 epoch 2
# Batch 42 of 937 epoch 2
# Batch 43 of 937 epoch 2
# Batch 44 of 937 epoch 2
# Batch 45 of 937 epoch 2
# Batch 46 of 937 epoch 2
# Batch 47 of 937 epoch 2
# Batch 48 of 937 epoch 2
# Batch 49 of 937 epoch 2
# Batch 50 of 937 epoch 2
# Batch 51 of 937 epoch 2
# Batch 52 of 937 epoch 2
# Batch 53 of 937 epoch 2
# Batch 54 of 937 epoch 2
# Batch 55 of 937 epoch 2
# Batch 56 of 937 epoch 2
# ...
# Batch 297 of 937 epoch 4
# Batch 298 of 937 epoch 4
# Batch 299 of 937 epoch 4
# Batch 300 of 937 epoch 4
# Batch 301 of 937 epoch 4
# Batch 302 of 937 epoch 4
# Batch 303 of 937 epoch 4
# Batch 304 of 937 epoch 4
# Batch 305 of 937 epoch 4
# Batch 306 of 937 epoch 4
# Batch 307 of 937 epoch 4
# Batch 308 of 937 epoch 4
# Batch 309 of 937 epoch 4
# Batch 310 of 937 epoch 4
# Batch 311 of 937 epoch 4
# Batch 312 of 937 epoch 4
# Batch 313 of 937 epoch 4
# Batch 314 of 937 epoch 4
# Batch 315 of 937 epoch 4
# Batch 316 of 937 epoch 4
# Batch 317 of 937 epoch 4
# Batch 318 of 937 epoch 4
# Batch 319 of 937 epoch 4
# Batch 320 of 937 epoch 4
# Batch 321 of 937 epoch 4
# Batch 322 of 937 epoch 4
# Batch 323 of 937 epoch 4
# Batch 324 of 937 epoch 4
# Batch 325 of 937 epoch 4
# Batch 326 of 937 epoch 4
# Batch 327 of 937 epoch 4
# Batch 328 of 937 epoch 4
# Batch 329 of 937 epoch 4
# Batch 330 of 937 epoch 4
# Batch 331 of 937 epoch 4
# Batch 332 of 937 epoch 4
# Batch 333 of 937 epoch 4
# Batch 334 of 937 epoch 4
# Batch 335 of 937 epoch 4
# Batch 336 of 937 epoch 4
# Batch 337 of 937 epoch 4
# Batch 338 of 937 epoch 4
# Batch 339 of 937 epoch 4
# Batch 340 of 937 epoch 4
# Batch 341 of 937 epoch 4
# Batch 342 of 937 epoch 4
# Batch 343 of 937 epoch 4
# Batch 344 of 937 epoch 4
# Batch 345 of 937 epoch 4
# Batch 346 of 937 epoch 4
# Batch 347 of 937 epoch 4
# Batch 348 of 937 epoch 4
# Batch 349 of 937 epoch 4
# Batch 350 of 937 epoch 4
# Batch 351 of 937 epoch 4
# Batch 352 of 937 epoch 4
# Batch 353 of 937 epoch 4
# Batch 354 of 937 epoch 4
# Batch 355 of 937 epoch 4
# Batch 356 of 937 epoch 4
# Batch 357 of 937 epoch 4
# Batch 358 of 937 epoch 4
# Batch 359 of 937 epoch 4
# Batch 360 of 937 epoch 4
# Batch 361 of 937 epoch 4
# Batch 362 of 937 epoch 4
# Batch 363 of 937 epoch 4
# Batch 364 of 937 epoch 4
# Batch 365 of 937 epoch 4
# Batch 366 of 937 epoch 4
# Batch 367 of 937 epoch 4
# Batch 368 of 937 epoch 4
# Batch 369 of 937 epoch 4
# Batch 370 of 937 epoch 4
# Batch 371 of 937 epoch 4
# Batch 372 of 937 epoch 4
# Batch 373 of 937 epoch 4
# Batch 374 of 937 epoch 4
# Batch 375 of 937 epoch 4
# Batch 376 of 937 epoch 4
# Batch 377 of 937 epoch 4
# Batch 378 of 937 epoch 4
# Batch 379 of 937 epoch 4
# Batch 380 of 937 epoch 4
# Batch 381 of 937 epoch 4
# Batch 382 of 937 epoch 4
# Batch 383 of 937 epoch 4
# Batch 384 of 937 epoch 4
# Batch 385 of 937 epoch 4
# Batch 386 of 937 epoch 4
# Batch 387 of 937 epoch 4
# Batch 388 of 937 epoch 4
# Batch 389 of 937 epoch 4
# Batch 390 of 937 epoch 4
# Batch 391 of 937 epoch 4
# Batch 392 of 937 epoch 4
# Batch 393 of 937 epoch 4
# Batch 394 of 937 epoch 4
# Batch 395 of 937 epoch 4
# Batch 396 of 937 epoch 4
# Batch 397 of 937 epoch 4
# Batch 398 of 937 epoch 4
# Batch 399 of 937 epoch 4
# Batch 400 of 937 epoch 4
# Batch 401 of 937 epoch 4
# Batch 402 of 937 epoch 4
# Batch 403 of 937 epoch 4
# Batch 404 of 937 epoch 4
# Batch 405 of 937 epoch 4
# Batch 406 of 937 epoch 4
# Batch 407 of 937 epoch 4
# Batch 408 of 937 epoch 4
# Batch 409 of 937 epoch 4
# Batch 410 of 937 epoch 4
# Batch 411 of 937 epoch 4
# Batch 412 of 937 epoch 4
# Batch 413 of 937 epoch 4
# Batch 414 of 937 epoch 4
# Batch 415 of 937 epoch 4
# Batch 416 of 937 epoch 4
# Batch 417 of 937 epoch 4
# Batch 418 of 937 epoch 4
# Batch 419 of 937 epoch 4
# Batch 420 of 937 epoch 4
# Batch 421 of 937 epoch 4
# Batch 422 of 937 epoch 4
# Batch 423 of 937 epoch 4
# Batch 424 of 937 epoch 4
# Batch 425 of 937 epoch 4
# Batch 426 of 937 epoch 4
# Batch 427 of 937 epoch 4
# Batch 428 of 937 epoch 4
# Batch 429 of 937 epoch 4
# Batch 430 of 937 epoch 4
# Batch 431 of 937 epoch 4
# Batch 432 of 937 epoch 4
# Batch 433 of 937 epoch 4
# Batch 434 of 937 epoch 4
# Batch 435 of 937 epoch 4
# Batch 436 of 937 epoch 4
# Batch 437 of 937 epoch 4
# Batch 438 of 937 epoch 4
# Batch 439 of 937 epoch 4
# Batch 440 of 937 epoch 4
# Batch 441 of 937 epoch 4
# Batch 442 of 937 epoch 4
# Batch 443 of 937 epoch 4
# Batch 444 of 937 epoch 4
# Batch 445 of 937 epoch 4
# Batch 446 of 937 epoch 4
# Batch 447 of 937 epoch 4
# Batch 448 of 937 epoch 4
# Batch 449 of 937 epoch 4
# Batch 450 of 937 epoch 4
# Batch 451 of 937 epoch 4
# Batch 452 of 937 epoch 4
# Batch 453 of 937 epoch 4
# Batch 454 of 937 epoch 4
# Batch 455 of 937 epoch 4
# Batch 456 of 937 epoch 4
# Batch 457 of 937 epoch 4
# Batch 458 of 937 epoch 4
# Batch 459 of 937 epoch 4
# Batch 460 of 937 epoch 4
# Batch 461 of 937 epoch 4
# Batch 462 of 937 epoch 4
# Batch 463 of 937 epoch 4
# Batch 464 of 937 epoch 4
# Batch 465 of 937 epoch 4
# Batch 466 of 937 epoch 4
# Batch 467 of 937 epoch 4
# Batch 468 of 937 epoch 4
# Batch 469 of 937 epoch 4
# Batch 470 of 937 epoch 4
# Batch 471 of 937 epoch 4
# Batch 472 of 937 epoch 4
# Batch 473 of 937 epoch 4
# Batch 474 of 937 epoch 4
# Batch 475 of 937 epoch 4
# Batch 476 of 937 epoch 4
# Batch 477 of 937 epoch 4
# Batch 478 of 937 epoch 4
# Batch 479 of 937 epoch 4
# Batch 480 of 937 epoch 4
# Batch 481 of 937 epoch 4
# Batch 482 of 937 epoch 4
# Batch 483 of 937 epoch 4
# Batch 484 of 937 epoch 4
# Batch 485 of 937 epoch 4
# Batch 486 of 937 epoch 4
# Batch 487 of 937 epoch 4
# Batch 488 of 937 epoch 4
# Batch 489 of 937 epoch 4
# Batch 490 of 937 epoch 4
# Batch 491 of 937 epoch 4
# Batch 492 of 937 epoch 4
# Batch 493 of 937 epoch 4
# Batch 494 of 937 epoch 4
# Batch 495 of 937 epoch 4
# Batch 496 of 937 epoch 4
# Batch 497 of 937 epoch 4
# Batch 498 of 937 epoch 4
# Batch 499 of 937 epoch 4
# Batch 500 of 937 epoch 4
# Batch 501 of 937 epoch 4
# Batch 502 of 937 epoch 4
# Batch 503 of 937 epoch 4
# Batch 504 of 937 epoch 4
# Batch 505 of 937 epoch 4
# Batch 506 of 937 epoch 4
# Batch 507 of 937 epoch 4
# Batch 508 of 937 epoch 4
# Batch 509 of 937 epoch 4
# Batch 510 of 937 epoch 4
# Batch 511 of 937 epoch 4
# Batch 512 of 937 epoch 4
# Batch 513 of 937 epoch 4
# Batch 514 of 937 epoch 4
# Batch 515 of 937 epoch 4
# Batch 516 of 937 epoch 4
# Batch 517 of 937 epoch 4
# Batch 518 of 937 epoch 4
# Batch 519 of 937 epoch 4
# Batch 520 of 937 epoch 4
# Batch 521 of 937 epoch 4
# Batch 522 of 937 epoch 4
# Batch 523 of 937 epoch 4
# Batch 524 of 937 epoch 4
# Batch 525 of 937 epoch 4
# Batch 526 of 937 epoch 4
# Batch 527 of 937 epoch 4
# Batch 528 of 937 epoch 4
# Batch 529 of 937 epoch 4
# Batch 530 of 937 epoch 4
# Batch 531 of 937 epoch 4
# Batch 532 of 937 epoch 4
# Batch 533 of 937 epoch 4
# Batch 534 of 937 epoch 4
# Batch 535 of 937 epoch 4
# Batch 536 of 937 epoch 4
# Batch 537 of 937 epoch 4
# Batch 538 of 937 epoch 4
# Batch 539 of 937 epoch 4
# Batch 540 of 937 epoch 4
# Batch 541 of 937 epoch 4
# Batch 542 of 937 epoch 4
# Batch 543 of 937 epoch 4
# Batch 544 of 937 epoch 4
# Batch 545 of 937 epoch 4
# Batch 546 of 937 epoch 4
# Batch 547 of 937 epoch 4
# Batch 548 of 937 epoch 4
# Batch 549 of 937 epoch 4
# Batch 550 of 937 epoch 4
# Batch 551 of 937 epoch 4
# Batch 552 of 937 epoch 4
# Batch 553 of 937 epoch 4
# Batch 554 of 937 epoch 4
# Batch 555 of 937 epoch 4
# Batch 556 of 937 epoch 4
# Batch 557 of 937 epoch 4
# Batch 558 of 937 epoch 4
# Batch 559 of 937 epoch 4
# Batch 560 of 937 epoch 4
# Batch 561 of 937 epoch 4
# Batch 562 of 937 epoch 4
# Batch 563 of 937 epoch 4
# Batch 564 of 937 epoch 4
# Batch 565 of 937 epoch 4
# Batch 566 of 937 epoch 4
# Batch 567 of 937 epoch 4
# Batch 568 of 937 epoch 4
# Batch 569 of 937 epoch 4
# Batch 570 of 937 epoch 4
# Batch 571 of 937 epoch 4
# Batch 572 of 937 epoch 4
# Batch 573 of 937 epoch 4
# Batch 574 of 937 epoch 4
# Batch 575 of 937 epoch 4
# Batch 576 of 937 epoch 4
# Batch 577 of 937 epoch 4
# Batch 578 of 937 epoch 4
# Batch 579 of 937 epoch 4
# Batch 580 of 937 epoch 4
# Batch 581 of 937 epoch 4
# Batch 582 of 937 epoch 4
# Batch 583 of 937 epoch 4
# Batch 584 of 937 epoch 4
# Batch 585 of 937 epoch 4
# Batch 586 of 937 epoch 4
# Batch 587 of 937 epoch 4
# Batch 588 of 937 epoch 4
# Batch 589 of 937 epoch 4
# Batch 590 of 937 epoch 4
# Batch 591 of 937 epoch 4
# Batch 592 of 937 epoch 4
# Batch 593 of 937 epoch 4
# Batch 594 of 937 epoch 4
# Batch 595 of 937 epoch 4
# Batch 596 of 937 epoch 4
# Batch 597 of 937 epoch 4
# Batch 598 of 937 epoch 4
# Batch 599 of 937 epoch 4
# Batch 600 of 937 epoch 4
# Batch 601 of 937 epoch 4
# Batch 602 of 937 epoch 4
# Batch 603 of 937 epoch 4
# Batch 604 of 937 epoch 4
# Batch 605 of 937 epoch 4
# Batch 606 of 937 epoch 4
# Batch 607 of 937 epoch 4
# Batch 608 of 937 epoch 4
# Batch 609 of 937 epoch 4
# Batch 610 of 937 epoch 4
# Batch 611 of 937 epoch 4
# Batch 612 of 937 epoch 4
# Batch 613 of 937 epoch 4
# Batch 614 of 937 epoch 4
# Batch 615 of 937 epoch 4
# Batch 616 of 937 epoch 4
# Batch 617 of 937 epoch 4
# Batch 618 of 937 epoch 4
# Batch 619 of 937 epoch 4
# Batch 620 of 937 epoch 4
# Batch 621 of 937 epoch 4
# Batch 622 of 937 epoch 4
# Batch 623 of 937 epoch 4
# Batch 624 of 937 epoch 4
# Batch 625 of 937 epoch 4
# Batch 626 of 937 epoch 4
# Batch 627 of 937 epoch 4
# Batch 628 of 937 epoch 4
# Batch 629 of 937 epoch 4
# Batch 630 of 937 epoch 4
# Batch 631 of 937 epoch 4
# Batch 632 of 937 epoch 4
# Batch 633 of 937 epoch 4
# Batch 634 of 937 epoch 4
# Batch 635 of 937 epoch 4
# Batch 636 of 937 epoch 4
# Batch 637 of 937 epoch 4
# Batch 638 of 937 epoch 4
# Batch 639 of 937 epoch 4
# Batch 640 of 937 epoch 4
# Batch 641 of 937 epoch 4
# Batch 642 of 937 epoch 4
# Batch 643 of 937 epoch 4
# Batch 644 of 937 epoch 4
# Batch 645 of 937 epoch 4
# Batch 646 of 937 epoch 4
# Batch 647 of 937 epoch 4
# Batch 648 of 937 epoch 4
# Batch 649 of 937 epoch 4
# Batch 650 of 937 epoch 4
# Batch 651 of 937 epoch 4
# Batch 652 of 937 epoch 4
# Batch 653 of 937 epoch 4
# Batch 654 of 937 epoch 4
# Batch 655 of 937 epoch 4
# Batch 656 of 937 epoch 4
# Batch 657 of 937 epoch 4
# Batch 658 of 937 epoch 4
# Batch 659 of 937 epoch 4
# Batch 660 of 937 epoch 4
# Batch 661 of 937 epoch 4
# Batch 662 of 937 epoch 4
# Batch 663 of 937 epoch 4
# Batch 664 of 937 epoch 4
# Batch 665 of 937 epoch 4
# Batch 666 of 937 epoch 4
# Batch 667 of 937 epoch 4
# Batch 668 of 937 epoch 4
# Batch 669 of 937 epoch 4
# Batch 670 of 937 epoch 4
# Batch 671 of 937 epoch 4
# Batch 672 of 937 epoch 4
# Batch 673 of 937 epoch 4
# Batch 674 of 937 epoch 4
# Batch 675 of 937 epoch 4
# Batch 676 of 937 epoch 4
# Batch 677 of 937 epoch 4
# Batch 678 of 937 epoch 4
# Batch 679 of 937 epoch 4
# Batch 680 of 937 epoch 4
# Batch 681 of 937 epoch 4
# Batch 682 of 937 epoch 4
# Batch 683 of 937 epoch 4
# Batch 684 of 937 epoch 4
# Batch 685 of 937 epoch 4
# Batch 686 of 937 epoch 4
# Batch 687 of 937 epoch 4
# Batch 688 of 937 epoch 4
# Batch 689 of 937 epoch 4
# Batch 690 of 937 epoch 4
# Batch 691 of 937 epoch 4
# Batch 692 of 937 epoch 4
# Batch 693 of 937 epoch 4
# Batch 694 of 937 epoch 4
# Batch 695 of 937 epoch 4
# Batch 696 of 937 epoch 4
# Batch 697 of 937 epoch 4
# Batch 698 of 937 epoch 4
# Batch 699 of 937 epoch 4
# Batch 700 of 937 epoch 4
# Batch 701 of 937 epoch 4
# Batch 702 of 937 epoch 4
# Batch 703 of 937 epoch 4
# Batch 704 of 937 epoch 4
# Batch 705 of 937 epoch 4
# Batch 706 of 937 epoch 4
# Batch 707 of 937 epoch 4
# Batch 708 of 937 epoch 4
# Batch 709 of 937 epoch 4
# Batch 710 of 937 epoch 4
# Batch 711 of 937 epoch 4
# Batch 712 of 937 epoch 4
# Batch 713 of 937 epoch 4
# Batch 714 of 937 epoch 4
# Batch 715 of 937 epoch 4
# Batch 716 of 937 epoch 4
# Batch 717 of 937 epoch 4
# Batch 718 of 937 epoch 4
# Batch 719 of 937 epoch 4
# Batch 720 of 937 epoch 4
# Batch 721 of 937 epoch 4
# Batch 722 of 937 epoch 4
# Batch 723 of 937 epoch 4
# Batch 724 of 937 epoch 4
# Batch 725 of 937 epoch 4
# Batch 726 of 937 epoch 4
# Batch 727 of 937 epoch 4
# Batch 728 of 937 epoch 4
# Batch 729 of 937 epoch 4
# Batch 730 of 937 epoch 4
# Batch 731 of 937 epoch 4
# Batch 732 of 937 epoch 4
# Batch 733 of 937 epoch 4
# Batch 734 of 937 epoch 4
# Batch 735 of 937 epoch 4
# Batch 736 of 937 epoch 4
# Batch 737 of 937 epoch 4
# Batch 738 of 937 epoch 4
# Batch 739 of 937 epoch 4
# Batch 740 of 937 epoch 4
# Batch 741 of 937 epoch 4
# Batch 742 of 937 epoch 4
# Batch 743 of 937 epoch 4
# Batch 744 of 937 epoch 4
# Batch 745 of 937 epoch 4
# Batch 746 of 937 epoch 4
# Batch 747 of 937 epoch 4
# Batch 748 of 937 epoch 4
# Batch 749 of 937 epoch 4
# Batch 750 of 937 epoch 4
# Batch 751 of 937 epoch 4
# Batch 752 of 937 epoch 4
# Batch 753 of 937 epoch 4
# Batch 754 of 937 epoch 4
# Batch 755 of 937 epoch 4
# Batch 756 of 937 epoch 4
# Batch 757 of 937 epoch 4
# Batch 758 of 937 epoch 4
# Batch 759 of 937 epoch 4
# Batch 760 of 937 epoch 4
# Batch 761 of 937 epoch 4
# Batch 762 of 937 epoch 4
# Batch 763 of 937 epoch 4
# Batch 764 of 937 epoch 4
# Batch 765 of 937 epoch 4
# Batch 766 of 937 epoch 4
# Batch 767 of 937 epoch 4
# Batch 768 of 937 epoch 4
# Batch 769 of 937 epoch 4
# Batch 770 of 937 epoch 4
# Batch 771 of 937 epoch 4
# Batch 772 of 937 epoch 4
# Batch 773 of 937 epoch 4
# Batch 774 of 937 epoch 4
# Batch 775 of 937 epoch 4
# Batch 776 of 937 epoch 4
# Batch 777 of 937 epoch 4
# Batch 778 of 937 epoch 4
# Batch 779 of 937 epoch 4
# Batch 780 of 937 epoch 4
# Batch 781 of 937 epoch 4
# Batch 782 of 937 epoch 4
# Batch 783 of 937 epoch 4
# Batch 784 of 937 epoch 4
# Batch 785 of 937 epoch 4
# Batch 786 of 937 epoch 4
# Batch 787 of 937 epoch 4
# Batch 788 of 937 epoch 4
# Batch 789 of 937 epoch 4
# Batch 790 of 937 epoch 4
# Batch 791 of 937 epoch 4
# Batch 792 of 937 epoch 4
# Batch 793 of 937 epoch 4
# Batch 794 of 937 epoch 4
# Batch 795 of 937 epoch 4
# Batch 796 of 937 epoch 4
# Batch 797 of 937 epoch 4
# Batch 798 of 937 epoch 4
# Batch 799 of 937 epoch 4
# Batch 800 of 937 epoch 4
# Batch 801 of 937 epoch 4
# Batch 802 of 937 epoch 4
# Batch 803 of 937 epoch 4
# Batch 804 of 937 epoch 4
# Batch 805 of 937 epoch 4
# Batch 806 of 937 epoch 4
# Batch 807 of 937 epoch 4
# Batch 808 of 937 epoch 4
# Batch 809 of 937 epoch 4
# Batch 810 of 937 epoch 4
# Batch 811 of 937 epoch 4
# Batch 812 of 937 epoch 4
# Batch 813 of 937 epoch 4
# Batch 814 of 937 epoch 4
# Batch 815 of 937 epoch 4
# Batch 816 of 937 epoch 4
# Batch 817 of 937 epoch 4
# Batch 818 of 937 epoch 4
# Batch 819 of 937 epoch 4
# Batch 820 of 937 epoch 4
# Batch 821 of 937 epoch 4
# Batch 822 of 937 epoch 4
# Batch 823 of 937 epoch 4
# Batch 824 of 937 epoch 4
# Batch 825 of 937 epoch 4
# Batch 826 of 937 epoch 4
# Batch 827 of 937 epoch 4
# Batch 828 of 937 epoch 4
# Batch 829 of 937 epoch 4
# Batch 830 of 937 epoch 4
# Batch 831 of 937 epoch 4
# Batch 832 of 937 epoch 4
# Batch 833 of 937 epoch 4
# Batch 834 of 937 epoch 4
# Batch 835 of 937 epoch 4
# Batch 836 of 937 epoch 4
# Batch 837 of 937 epoch 4
# Batch 838 of 937 epoch 4
# Batch 839 of 937 epoch 4
# Batch 840 of 937 epoch 4
# Batch 841 of 937 epoch 4
# Batch 842 of 937 epoch 4
# Batch 843 of 937 epoch 4
# Batch 844 of 937 epoch 4
# Batch 845 of 937 epoch 4
# Batch 846 of 937 epoch 4
# Batch 847 of 937 epoch 4
# Batch 848 of 937 epoch 4
# Batch 849 of 937 epoch 4
# Batch 850 of 937 epoch 4
# Batch 851 of 937 epoch 4
# Batch 852 of 937 epoch 4
# Batch 853 of 937 epoch 4
# Batch 854 of 937 epoch 4
# Batch 855 of 937 epoch 4
# Batch 856 of 937 epoch 4
# Batch 857 of 937 epoch 4
# Batch 858 of 937 epoch 4
# Batch 859 of 937 epoch 4
# Batch 860 of 937 epoch 4
# Batch 861 of 937 epoch 4
# Batch 862 of 937 epoch 4
# Batch 863 of 937 epoch 4
# Batch 864 of 937 epoch 4
# Batch 865 of 937 epoch 4
# Batch 866 of 937 epoch 4
# Batch 867 of 937 epoch 4
# Batch 868 of 937 epoch 4
# Batch 869 of 937 epoch 4
# Batch 870 of 937 epoch 4
# Batch 871 of 937 epoch 4
# Batch 872 of 937 epoch 4
# Batch 873 of 937 epoch 4
# Batch 874 of 937 epoch 4
# Batch 875 of 937 epoch 4
# Batch 876 of 937 epoch 4
# Batch 877 of 937 epoch 4
# Batch 878 of 937 epoch 4
# Batch 879 of 937 epoch 4
# Batch 880 of 937 epoch 4
# Batch 881 of 937 epoch 4
# Batch 882 of 937 epoch 4
# Batch 883 of 937 epoch 4
# Batch 884 of 937 epoch 4
# Batch 885 of 937 epoch 4
# Batch 886 of 937 epoch 4
# Batch 887 of 937 epoch 4
# Batch 888 of 937 epoch 4
# Batch 889 of 937 epoch 4
# Batch 890 of 937 epoch 4
# Batch 891 of 937 epoch 4
# Batch 892 of 937 epoch 4
# Batch 893 of 937 epoch 4
# Batch 894 of 937 epoch 4
# Batch 895 of 937 epoch 4
# Batch 896 of 937 epoch 4
# Batch 897 of 937 epoch 4
# Batch 898 of 937 epoch 4
# Batch 899 of 937 epoch 4
# Batch 900 of 937 epoch 4
# Batch 901 of 937 epoch 4
# Batch 902 of 937 epoch 4
# Batch 903 of 937 epoch 4
# Batch 904 of 937 epoch 4
# Batch 905 of 937 epoch 4
# Batch 906 of 937 epoch 4
# Batch 907 of 937 epoch 4
# Batch 908 of 937 epoch 4
# Batch 909 of 937 epoch 4
# Batch 910 of 937 epoch 4
# Batch 911 of 937 epoch 4
# Batch 912 of 937 epoch 4
# Batch 913 of 937 epoch 4
# Batch 914 of 937 epoch 4
# Batch 915 of 937 epoch 4
# Batch 916 of 937 epoch 4
# Batch 917 of 937 epoch 4
# Batch 918 of 937 epoch 4
# Batch 919 of 937 epoch 4
# Batch 920 of 937 epoch 4
# Batch 921 of 937 epoch 4
# Batch 922 of 937 epoch 4
# Batch 923 of 937 epoch 4
# Batch 924 of 937 epoch 4
# Batch 925 of 937 epoch 4
# Batch 926 of 937 epoch 4
# Batch 927 of 937 epoch 4
# Batch 928 of 937 epoch 4
# Batch 929 of 937 epoch 4
# Batch 930 of 937 epoch 4
# Batch 931 of 937 epoch 4
# Batch 932 of 937 epoch 4
# Batch 933 of 937 epoch 4
# Batch 934 of 937 epoch 4
# Batch 935 of 937 epoch 4
# Batch 936 of 937 epoch 4

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [10, 5]

fig, ax = plt.subplots(1)

ax.plot(np.array(acc_list), color='tab:blue')
ax.set_xlabel('mini-batch steps (100)')
ax.set_ylabel('LeNet accuracy')
ax.tick_params(colors='tab:blue', axis='y')

ax2 = ax.twinx()
ax2.plot(np.array(loss_list), color='tab:red')
ax2.set_ylabel('LeNet loss')
ax2.tick_params(colors='tab:red', axis='y')
ax.set_title('LeNet training')
# Out:
# Text(0.5, 1.0, 'LeNet training')

# %% [markdown]
# You can save your training state by using `state_dict = net.state_dict()` and `torch.save(state_dict, 'lenet_new.pt')`
#
# <span style="color:green">Your Task:</span>
# * <span style="color:green">Save the state dict of the model with a new name and plug it into exercise 01 by changing the file name in Cell 9</span>

# %%
#save model here
#---to-be-done-by-student---
torch.save(net.state_dict(), 'lenet_new.pt')
#---end---------------------
